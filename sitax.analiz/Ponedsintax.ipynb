# %%
! pip install spacy
! python -m spacy download ru_core_news_sm
# %pip install natasha
# Out:
# ...
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      --------------------------------------- 0.0/15.3 MB 145.2 kB/s eta 0:01:45
#      --------------------------------------- 0.0/15.3 MB 145.2 kB/s eta 0:01:45
#      --------------------------------------- 0.0/15.3 MB 140.3 kB/s eta 0:01:49
#      --------------------------------------- 0.0/15.3 MB 140.3 kB/s eta 0:01:49
#      --------------------------------------- 0.1/15.3 MB 155.6 kB/s eta 0:01:38
#      --------------------------------------- 0.1/15.3 MB 155.6 kB/s eta 0:01:38
#      --------------------------------------- 0.1/15.3 MB 145.6 kB/s eta 0:01:45
# ...

# %%
import spacy
from spacy import displacy

nlp = spacy.load('ru_core_news_sm')

with open("Понедельник начинается в субботу.txt", "r", encoding="utf-8") as file:
    text = file.read()

doc = nlp(text)

for token in doc:
    print(token.text, "\t", token.pos_)
# Out:
#
#                                       	 SPACE
# ИСТОРИЯ 	 NOUN
# ПЕРВАЯ 	 PROPN
#
#
#                                    	 SPACE
# Суета 	 PROPN
# вокруг 	 ADP
# дивана 	 NOUN
#
#
#     	 SPACE
# УЧИТЕЛЬ 	 PROPN
# : 	 PUNCT
# Дети 	 NOUN
# , 	 PUNCT
# запишите 	 VERB
# предложение 	 NOUN
# : 	 PUNCT
# « 	 PUNCT
# Рыба 	 NOUN
# сидела 	 VERB
# на 	 ADP
# дереве 	 NOUN
# » 	 PUNCT
# . 	 PUNCT
#
#
#     	 SPACE
# УЧЕНИК 	 NOUN
# : 	 PUNCT
# А 	 CCONJ
# разве 	 PART
# рыбы 	 NOUN
# сидят 	 VERB
# на 	 ADP
# деревьях 	 NOUN
# ? 	 PUNCT
#
#
#     	 SPACE
# УЧИТЕЛЬ 	 NOUN
# : 	 PUNCT
# Ну 	 PART
# … 	 PUNCT
# Это 	 PRON
# была 	 AUX
# сумасшедшая 	 ADJ
# рыба 	 NOUN
# . 	 PUNCT
#
#
#  	 SPACE
# Школьный 	 ADJ
# анекдот 	 NOUN
#
#
#      	 SPACE
# приближался 	 VERB
# к 	 ADP
# месту 	 NOUN
# моего 	 DET
# назначения 	 NOUN
# . 	 PUNCT
# Вокруг 	 ADP
# меня 	 PRON
# , 	 PUNCT
# прижимаясь 	 VERB
# к 	 ADP
# самой 	 ADJ
# дороге 	 NOUN
# , 	 PUNCT
#
#  	 SPACE
# зеленел 	 VERB
# лес 	 NOUN
# ...

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="c74f34c5bf054e438b488b3bae5e21e6-0" class="displacy" width="543950" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
#                                      </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">ИСТОРИЯ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
# ...

# %%
from natasha import Segmenter, NewsEmbedding, NewsSyntaxParser, Doc

emb = NewsEmbedding()

segmenter = Segmenter()

syntax_parser = NewsSyntaxParser(emb)

text = 'УЧИТЕЛЬ: Дети, запишите предложение: «Рыба сидела на дереве».'

doc = Doc(text)

doc.segment(segmenter)

for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(stop=7, text='УЧИТЕЛЬ')
# DocToken(start=7, stop=8, text=':')
# DocToken(start=9, stop=13, text='Дети')
# DocToken(start=13, stop=14, text=',')
# DocToken(start=15, stop=23, text='запишите')
# DocToken(start=24, stop=35, text='предложение')
# DocToken(start=35, stop=36, text=':')
# DocToken(start=37, stop=38, text='«')
# DocToken(start=38, stop=42, text='Рыба')
# DocToken(start=43, stop=49, text='сидела')
# DocToken(start=50, stop=52, text='на')
# DocToken(start=53, stop=59, text='дереве')
# DocToken(start=59, stop=60, text='»')
# DocToken(start=60, stop=61, text='.')

# %%
doc.parse_syntax(syntax_parser)

for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(stop=7, text='УЧИТЕЛЬ', id='1_1', head_id='1_0', rel='root')
# DocToken(start=7, stop=8, text=':', id='1_2', head_id='1_3', rel='punct')
# DocToken(start=9, stop=13, text='Дети', id='1_3', head_id='1_1', rel='parataxis')
# DocToken(start=13, stop=14, text=',', id='1_4', head_id='1_5', rel='punct')
# DocToken(start=15, stop=23, text='запишите', id='1_5', head_id='1_1', rel='parataxis')
# DocToken(start=24, stop=35, text='предложение', id='1_6', head_id='1_5', rel='obj')
# DocToken(start=35, stop=36, text=':', id='1_7', head_id='1_10', rel='punct')
# DocToken(start=37, stop=38, text='«', id='1_8', head_id='1_10', rel='punct')
# DocToken(start=38, stop=42, text='Рыба', id='1_9', head_id='1_10', rel='nsubj')
# DocToken(start=43, stop=49, text='сидела', id='1_10', head_id='1_6', rel='parataxis')
# DocToken(start=50, stop=52, text='на', id='1_11', head_id='1_12', rel='case')
# DocToken(start=53, stop=59, text='дереве', id='1_12', head_id='1_10', rel='obl')
# ...

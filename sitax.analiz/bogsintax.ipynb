0 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from natasha) (0.6.0)
# Requirement already satisfied: yargy>=0.16.0 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from natasha) (0.16.0)
# Requirement already satisfied: ipymarkup>=0.8.0 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from natasha) (0.9.0)
# Requirement already satisfied: intervaltree>=3 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from ipymarkup>=0.8.0->natasha) (3.1.0)
# Requirement already satisfied: numpy in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from navec>=0.9.0->natasha) (1.26.0)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from pymorphy2->natasha) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from pymorphy2->natasha) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from pymorphy2->natasha) (0.6.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\хороший человек\appdata\local\programs\python\python312\lib\site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
from spacy import displacy

nlp = spacy.load('ru_core_news_sm')

with open("Трудно быть богом.txt", "r", encoding="utf-8") as file:
    text = file.read()

doc = nlp(text)

for token in doc:
    print(token.text, "\t", token.pos_)
# Out:
#
#       	 SPACE
# Ложа 	 PROPN
# Анкиного 	 ADJ
# арбалета 	 NOUN
# была 	 AUX
# выточена 	 VERB
# из 	 ADP
# черной 	 ADJ
# пластмассы 	 NOUN
# , 	 PUNCT
# а 	 CCONJ
# тетива 	 NOUN
# была 	 AUX
# из 	 ADP
#
#  	 SPACE
# хромистой 	 ADJ
# стали 	 NOUN
# и 	 CCONJ
# натягивалась 	 VERB
# одним 	 NUM
# движением 	 NOUN
# бесшумно 	 ADV
# скользящего 	 VERB
# рычага 	 NOUN
# . 	 PUNCT
# Антон 	 PROPN
#
#  	 SPACE
# новшеств 	 NOUN
# не 	 PART
# признавал 	 VERB
# : 	 PUNCT
# у 	 ADP
# него 	 PRON
# было 	 VERB
# доброе 	 ADJ
# боевое 	 ADJ
# устройство 	 NOUN
# в 	 ADP
# стиле 	 NOUN
# маршала 	 NOUN
# Тоца 	 PROPN
# , 	 PUNCT
# короля 	 NOUN
#
#  	 SPACE
# Пица 	 NOUN
# Первого 	 ADJ
# , 	 PUNCT
# окованное 	 VERB
# черной 	 ADJ
# медью 	 NOUN
# , 	 PUNCT
# с 	 ADP
# колесиком 	 NOUN
# , 	 PUNCT
# на 	 ADP
# которое 	 PRON
# наматывался 	 VERB
# шнур 	 NOUN
# из 	 ADP
#
#  	 SPACE
# воловьих 	 ADJ
# жил 	 VERB
# . 	 PUNCT
# Что 	 PRON
# касается 	 VERB
# Пашки 	 NOUN
# , 	 PUNCT
# то 	 SCONJ
# он 	 PRON
# взял 	 VERB
# пневматический 	 ADJ
# карабин 	 NOUN
# . 	 PUNCT
# Арбалеты 	 NOUN
# он 	 PRON
# считал 	 VERB
#
#  	 SPACE
# детством 	 NOUN
# человечества 	 NOUN
# , 	 PUNCT
# так 	 ADV
# как 	 SCONJ
# был 	 AUX
# ленив 	 VERB
# и 	 CCONJ
# неспособен 	 ADJ
# к 	 ADP
# столярному 	 ADJ
# ремеслу 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Они 	 PRON
# причалили 	 VERB
# к 	 ADP
# северному 	 ADJ
# берегу 	 NOUN
# , 	 PUNCT
# где 	 ADV
# из 	 ADP
# желтого 	 ADJ
# песчаного 	 ADJ
# обрыва 	 NOUN
# торчали 	 VERB
# корявые 	 ADJ
#
#  	 SPACE
# корни 	 NOUN
# мачтовых 	 ADJ
# сосен 	 NOUN
# . 	 PUNCT
# Анка 	 NOUN
# бросила 	 VERB
# рулевое 	 ADJ
# весло 	 NOUN
# и 	 CCONJ
# оглянулась 	 VERB
# . 	 PUNCT
# Солнце 	 NOUN
# уже 	 ADV
# поднялось 	 VERB
# над 	 ADP
#
#  	 SPACE
# лесом 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# все 	 PRON
# было 	 AUX
# голубое 	 ADJ
# зеленое 	 ADJ
# и 	 CCONJ
# желтое 	 ADJ
# — 	 PUNCT
# голубой 	 ADJ
# туман 	 NOUN
# над 	 ADP
# озером 	 NOUN
# , 	 PUNCT
# темно 	 ADJ
# - 	 ADJ
# зеленые 	 ADJ
#
#  	 SPACE
# сосны 	 NOUN
# и 	 CCONJ
# желтый 	 ADJ
# берег 	 NOUN
# на 	 ADP
# той 	 DET
# стороне 	 NOUN
# . 	 PUNCT
# И 	 CCONJ
# небо 	 NOUN
# над 	 ADP
# всем 	 DET
# этим 	 PRON
# было 	 AUX
# ясное 	 ADJ
# , 	 PUNCT
# белесовато 	 ADJ
# - 	 ADJ
# синее 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ничего 	 PRON
# там 	 ADV
# нет 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# Ребята 	 NOUN
# сидели 	 VERB
# , 	 PUNCT
# перегнувшись 	 VERB
# через 	 ADP
# борт 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# глядели 	 VERB
# в 	 ADP
# воду 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Громадная 	 ADJ
# щука 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# уверенно 	 ADV
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# С 	 ADP
# вот 	 PART
# такими 	 DET
# плавниками 	 NOUN
# ? 	 PUNCT
# — 	 PUNCT
# спросил 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# промолчал 	 VERB
# . 	 PUNCT
# Анка 	 NOUN
# тоже 	 ADV
# посмотрела 	 VERB
# в 	 ADP
# воду 	 NOUN
# , 	 PUNCT
# но 	 CCONJ
# увидела 	 VERB
# только 	 PART
# собственное 	 ADJ
#
#  	 SPACE
# отражение 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Искупаться 	 VERB
# бы 	 AUX
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# , 	 PUNCT
# запуская 	 VERB
# руку 	 NOUN
# по 	 ADP
# локоть 	 NOUN
# в 	 ADP
# воду 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Холодная 	 ADJ
# , 	 PUNCT
# — 	 PUNCT
#
#  	 SPACE
# сообщил 	 VERB
# он 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# перебрался 	 VERB
# на 	 ADP
# нос 	 NOUN
# и 	 CCONJ
# спрыгнул 	 VERB
# на 	 ADP
# берег 	 NOUN
# . 	 PUNCT
# Лодка 	 NOUN
# закачалась 	 VERB
# . 	 PUNCT
# Антон 	 PROPN
# взялся 	 VERB
# за 	 ADP
# борт 	 NOUN
#
#  	 SPACE
# и 	 CCONJ
# выжидательно 	 ADV
# посмотрел 	 VERB
# на 	 ADP
# Пашку 	 PROPN
# . 	 PUNCT
# Тогда 	 ADV
# Пашка 	 PROPN
# поднялся 	 VERB
# , 	 PUNCT
# заложил 	 VERB
# весло 	 VERB
# за 	 ADP
# шею 	 NOUN
# , 	 PUNCT
# как 	 SCONJ
#
#  	 SPACE
# коромысло 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# , 	 PUNCT
# извиваясь 	 VERB
# нижней 	 ADJ
# частью 	 NOUN
# туловища 	 NOUN
# , 	 PUNCT
# пропел 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# Старый 	 ADJ
# шкипер 	 NOUN
# Вицлипуцли 	 PROPN
# ! 	 PUNCT
#
#       	 SPACE
# Ты 	 PRON
# , 	 PUNCT
# приятель 	 NOUN
# , 	 PUNCT
# не 	 PART
# заснул 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# Берегись 	 VERB
# , 	 PUNCT
# к 	 ADP
# тебе 	 PRON
# несутся 	 VERB
#
#       	 SPACE
# Стаи 	 NOUN
# жареных 	 ADJ
# акул 	 NOUN
# ! 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# молча 	 ADV
# рванул 	 VERB
# лодку 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Эй 	 INTJ
# - 	 INTJ
# эй 	 INTJ
# ! 	 PUNCT
# — 	 PUNCT
# закричал 	 VERB
# Пашка 	 PROPN
# , 	 PUNCT
# хватаясь 	 VERB
# за 	 ADP
# борта 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Почему 	 ADV
# жареных 	 ADJ
# ? 	 PUNCT
# — 	 PUNCT
# спросила 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Не 	 PART
# знаю 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# ответил 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# Они 	 PRON
# выбрались 	 VERB
# из 	 ADP
# лодки 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# А 	 CCONJ
# верно 	 ADV
# здорово 	 ADJ
# ? 	 PUNCT
# Стаи 	 NOUN
#
#  	 SPACE
# жареных 	 ADJ
# акул 	 NOUN
# ! 	 PUNCT
#
#       	 SPACE
# Они 	 PRON
# потащили 	 VERB
# лодку 	 NOUN
# на 	 ADP
# берег 	 NOUN
# . 	 PUNCT
# Ноги 	 NOUN
# проваливались 	 VERB
# во 	 ADP
# влажный 	 ADJ
# песок 	 NOUN
# , 	 PUNCT
# где 	 ADV
# было 	 AUX
#
#  	 SPACE
# полным 	 ADJ
# - 	 ADJ
# полно 	 ADV
# высохших 	 VERB
# иголок 	 NOUN
# и 	 CCONJ
# сосновых 	 ADJ
# шишек 	 NOUN
# . 	 PUNCT
# Лодка 	 NOUN
# была 	 AUX
# тяжелая 	 ADJ
# и 	 CCONJ
# скользкая 	 ADJ
# , 	 PUNCT
# но 	 CCONJ
#
#  	 SPACE
# они 	 PRON
# выволокли 	 VERB
# ее 	 PRON
# до 	 ADP
# самой 	 ADJ
# кормы 	 NOUN
# и 	 CCONJ
# остановились 	 VERB
# , 	 PUNCT
# тяжело 	 ADJ
# дыша 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ногу 	 PROPN
# отдавил 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# и 	 CCONJ
# принялся 	 VERB
# поправлять 	 VERB
# красную 	 ADJ
# повязку 	 NOUN
# на 	 ADP
# голове 	 NOUN
# . 	 PUNCT
#
#  	 SPACE
# Он 	 PRON
# внимательно 	 ADV
# следил 	 VERB
# за 	 ADP
# тем 	 PRON
# , 	 PUNCT
# чтобы 	 SCONJ
# узел 	 NOUN
# повязки 	 NOUN
# был 	 AUX
# точно 	 ADV
# над 	 ADP
# правым 	 ADJ
# ухом 	 NOUN
# , 	 PUNCT
# как 	 SCONJ
# у 	 ADP
#
#  	 SPACE
# носатых 	 ADJ
# ируканских 	 ADJ
# пиратов 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Жизнь 	 NOUN
# не 	 PART
# дорога 	 NOUN
# , 	 PUNCT
# о 	 INTJ
# - 	 ADV
# хэй 	 ADV
# ! 	 PUNCT
# — 	 PUNCT
# заявил 	 VERB
# он 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# Анка 	 NOUN
# сосредоточенно 	 ADV
# сосала 	 VERB
# палец 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Занозила 	 PROPN
# ? 	 PUNCT
# — 	 PUNCT
# спросил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Нет 	 PART
# . 	 PUNCT
# Содрала 	 VERB
# . 	 PUNCT
# У 	 ADP
# кого 	 PRON
# - 	 PRON
# то 	 PRON
# из 	 ADP
# вас 	 PRON
# такие 	 DET
# когти 	 NOUN
# … 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ну 	 PART
# - 	 NOUN
# ка 	 NOUN
# , 	 PUNCT
# покажи 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Она 	 PRON
# показала 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Да 	 PART
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Травма 	 NOUN
# . 	 PUNCT
# Ну 	 PART
# , 	 PUNCT
# что 	 PRON
# будем 	 AUX
# делать 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# На 	 ADP
# пле 	 NOUN
# - 	 NOUN
# чо 	 NOUN
# — 	 PUNCT
# и 	 CCONJ
# вдоль 	 ADP
# берега 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# предложил 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Стоило 	 VERB
# тогда 	 ADV
# вылезать 	 VERB
# из 	 ADP
# лодки 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# На 	 ADP
# лодке 	 NOUN
# и 	 CCONJ
# курица 	 NOUN
# может 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# объяснил 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# А 	 CCONJ
# по 	 ADP
# берегу 	 NOUN
# : 	 PUNCT
# тростники 	 NOUN
# — 	 PUNCT
# раз 	 NOUN
# , 	 PUNCT
#
#  	 SPACE
# обрывы 	 NOUN
# — 	 PUNCT
# два 	 NUM
# , 	 PUNCT
# омуты 	 VERB
# — 	 PUNCT
# три 	 NUM
# . 	 PUNCT
# С 	 ADP
# налимами 	 NOUN
# . 	 PUNCT
# И 	 CCONJ
# сомы 	 NOUN
# есть 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Стаи 	 NOUN
# жареных 	 ADJ
# сомов 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# ты 	 PRON
# в 	 ADP
# омут 	 VERB
# нырял 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ну 	 PART
# , 	 PUNCT
# нырял 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Я 	 PRON
# не 	 PART
# видел 	 VERB
# . 	 PUNCT
# Не 	 PART
# довелось 	 VERB
# как 	 ADV
# - 	 ADV
# то 	 ADV
# увидеть 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Мало 	 ADV
# ли 	 PART
# чего 	 PRON
# ты 	 PRON
# не 	 PART
# видел 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# Анка 	 NOUN
# повернулась 	 VERB
# к 	 ADP
# ним 	 PRON
# спиной 	 NOUN
# , 	 PUNCT
# подняла 	 VERB
# арбалет 	 NOUN
# и 	 CCONJ
# выстрелила 	 VERB
# в 	 ADP
# сосну 	 NOUN
# шагах 	 NOUN
# в 	 ADP
#
#  	 SPACE
# двадцати 	 NUM
# . 	 PUNCT
# Посыпалась 	 VERB
# кора 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Здорово 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# и 	 CCONJ
# сейчас 	 ADV
# же 	 PART
# выстрелил 	 VERB
# из 	 ADP
# карабина 	 NOUN
# . 	 PUNCT
# Он 	 PRON
# целился 	 VERB
# в 	 ADP
# Анкину 	 PROPN
#
#  	 SPACE
# стрелу 	 NOUN
# , 	 PUNCT
# но 	 CCONJ
# промазал 	 VERB
# . 	 PUNCT
# — 	 PUNCT
# Дыхание 	 NOUN
# не 	 PART
# задержал 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# объяснил 	 VERB
# он 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# если 	 SCONJ
# бы 	 AUX
# задержал 	 VERB
# ? 	 PUNCT
# — 	 PUNCT
# спросил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# Он 	 PRON
# смотрел 	 VERB
# на 	 ADP
# Анку 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# Анка 	 NOUN
# сильным 	 ADJ
# движением 	 NOUN
# оттянула 	 VERB
# рычаг 	 NOUN
# тетивы 	 NOUN
# . 	 PUNCT
# Мускулы 	 NOUN
# у 	 ADP
# нее 	 PRON
# были 	 VERB
# отличные 	 ADJ
# — 	 PUNCT
#
#  	 SPACE
# Антон 	 PROPN
# с 	 ADP
# удовольствием 	 NOUN
# смотрел 	 VERB
# , 	 PUNCT
# как 	 ADV
# прокатился 	 VERB
# под 	 ADP
# смуглой 	 ADJ
# кожей 	 NOUN
# твердый 	 ADJ
# шарик 	 NOUN
# бицепса 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Анка 	 NOUN
# очень 	 ADV
# тщательно 	 ADV
# прицелилась 	 VERB
# и 	 CCONJ
# выстрелила 	 VERB
# еще 	 ADV
# раз 	 NOUN
# . 	 PUNCT
# Вторая 	 ADJ
# стрела 	 NOUN
# с 	 ADP
# треском 	 NOUN
#
#  	 SPACE
# воткнулась 	 VERB
# в 	 ADP
# ствол 	 NOUN
# немного 	 ADV
# ниже 	 ADJ
# первой 	 ADJ
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Зря 	 PROPN
# мы 	 PRON
# это 	 PRON
# делаем 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# , 	 PUNCT
# опуская 	 ADJ
# арбалет 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Что 	 PRON
# ? 	 PUNCT
# — 	 PUNCT
# спросил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Деревья 	 NOUN
# портим 	 VERB
# , 	 PUNCT
# вот 	 PART
# что 	 PRON
# . 	 PUNCT
# Один 	 NUM
# малек 	 NOUN
# вчера 	 ADV
# стрелял 	 VERB
# в 	 ADP
# дерево 	 NOUN
# из 	 ADP
# лука 	 NOUN
# , 	 PUNCT
# так 	 ADV
# я 	 PRON
# его 	 PRON
#
#  	 SPACE
# заставила 	 VERB
# зубами 	 NOUN
# стрелы 	 NOUN
# выдергивать 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Пашка 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Сбегал 	 VERB
# бы 	 AUX
# , 	 PUNCT
# у 	 ADP
# тебя 	 PRON
# зубы 	 NOUN
# хорошие 	 ADJ
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# У 	 ADP
# меня 	 PRON
# зуб 	 NOUN
# со 	 ADP
# свистом 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# ответил 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ладно 	 PART
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Давайте 	 VERB
# что 	 PRON
# - 	 PRON
# нибудь 	 PRON
# делать 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Неохота 	 PROPN
# мне 	 PRON
# лазить 	 VERB
# по 	 ADP
# обрывам 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Мне 	 PRON
# тоже 	 ADV
# неохота 	 NOUN
# . 	 PUNCT
# Пошли 	 VERB
# прямо 	 ADV
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Куда 	 ADV
# ? 	 PUNCT
# — 	 PUNCT
# спросил 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Куда 	 ADV
# глаза 	 NOUN
# глядят 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ну 	 PART
# ? 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Значит 	 VERB
# , 	 PUNCT
# в 	 ADP
# сайву 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Тошка 	 PROPN
# , 	 PUNCT
# пошли 	 VERB
# на 	 ADP
# Забытое 	 ADJ
# Шоссе 	 PROPN
# . 	 PUNCT
# Помнишь 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Еще 	 ADV
# бы 	 AUX
# ! 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Знаешь 	 VERB
# , 	 PUNCT
# Анечка 	 PROPN
# … 	 PUNCT
# — 	 PUNCT
# начал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Я 	 PRON
# тебе 	 PRON
# не 	 PART
# Анечка 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# резко 	 ADV
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
# Она 	 PRON
# терпеть 	 VERB
# не 	 PART
# могла 	 VERB
# , 	 PUNCT
# когда 	 SCONJ
# ее 	 PRON
# называли 	 VERB
# не 	 PART
#
#  	 SPACE
# Анка 	 PROPN
# , 	 PUNCT
# а 	 CCONJ
# как 	 ADV
# - 	 ADV
# нибудь 	 ADV
# еще 	 ADV
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# это 	 PRON
# хорошо 	 ADV
# запомнил 	 VERB
# . 	 PUNCT
# Он 	 PRON
# быстро 	 ADV
# сказал 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Забытое 	 ADJ
# Шоссе 	 PROPN
# . 	 PUNCT
# По 	 ADP
# нему 	 PRON
# не 	 PART
# ездят 	 VERB
# . 	 PUNCT
# И 	 CCONJ
# на 	 ADP
# карте 	 NOUN
# его 	 PRON
# нет 	 VERB
# . 	 PUNCT
# И 	 CCONJ
# куда 	 ADV
# идет 	 VERB
# , 	 PUNCT
# совершенно 	 ADV
#
#  	 SPACE
# неизвестно 	 ADJ
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# вы 	 PRON
# там 	 ADV
# были 	 AUX
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Были 	 VERB
# . 	 PUNCT
# Но 	 CCONJ
# не 	 PART
# успели 	 VERB
# исследовать 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Дорога 	 PROPN
# из 	 ADP
# ниоткуда 	 ADV
# в 	 ADP
# никуда 	 ADV
# , 	 PUNCT
# — 	 PUNCT
# изрек 	 NOUN
# оправившийся 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Это 	 PRON
# здорово 	 ADJ
# ! 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
# Глаза 	 NOUN
# у 	 ADP
# нее 	 PRON
# стали 	 VERB
# как 	 SCONJ
# черные 	 ADJ
# щелки 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Пошли 	 VERB
# . 	 PUNCT
# К 	 ADP
#
#  	 SPACE
# вечеру 	 NOUN
# дойдем 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ну 	 PART
# что 	 PRON
# ты 	 PRON
# ! 	 PUNCT
# До 	 ADP
# двенадцати 	 NUM
# дойдем 	 VERB
# . 	 PUNCT
#
#        	 SPACE
# Они 	 PRON
# полезли 	 VERB
# вверх 	 ADV
# по 	 ADP
# обрыву 	 NOUN
# . 	 PUNCT
# На 	 ADP
# краю 	 NOUN
# обрыва 	 NOUN
# Пашка 	 PROPN
# обернулся 	 VERB
# . 	 PUNCT
# Внизу 	 ADV
# было 	 AUX
# синее 	 ADJ
#
#  	 SPACE
# озеро 	 NOUN
# с 	 ADP
# желтоватыми 	 ADJ
# проплешинами 	 NOUN
# отмелей 	 NOUN
# , 	 PUNCT
# лодка 	 NOUN
# на 	 ADP
# песке 	 NOUN
# и 	 CCONJ
# большие 	 ADJ
# расходящиеся 	 VERB
# круги 	 NOUN
#
#  	 SPACE
# на 	 ADP
# спокойной 	 ADJ
# маслянистой 	 ADJ
# воде 	 NOUN
# у 	 ADP
# берега 	 NOUN
# — 	 PUNCT
# вероятно 	 ADV
# , 	 PUNCT
# это 	 PRON
# плеснула 	 VERB
# та 	 DET
# самая 	 ADJ
# щука 	 NOUN
# . 	 PUNCT
# И 	 CCONJ
# Пашка 	 PROPN
#
#  	 SPACE
# ощутил 	 VERB
# обычный 	 ADJ
# неопределенный 	 ADJ
# восторг 	 NOUN
# , 	 PUNCT
# как 	 SCONJ
# всегда 	 ADV
# , 	 PUNCT
# когда 	 SCONJ
# они 	 PRON
# с 	 ADP
# Тошкой 	 PROPN
# удирали 	 VERB
# из 	 ADP
#
#  	 SPACE
# интерната 	 NOUN
# и 	 CCONJ
# впереди 	 ADV
# был 	 AUX
# день 	 NOUN
# полной 	 ADJ
# независимости 	 NOUN
# с 	 ADP
# неразведанными 	 ADJ
# местами 	 NOUN
# , 	 PUNCT
# с 	 ADP
#
#  	 SPACE
# земляникой 	 NOUN
# , 	 PUNCT
# с 	 ADP
# горячими 	 ADJ
# безлюдными 	 ADJ
# лугами 	 NOUN
# , 	 PUNCT
# с 	 ADP
# серыми 	 ADJ
# ящерицами 	 NOUN
# , 	 PUNCT
# с 	 ADP
# ледяной 	 ADJ
# водой 	 NOUN
# в 	 ADP
#
#  	 SPACE
# неожиданных 	 ADJ
# родниках 	 NOUN
# . 	 PUNCT
# И 	 CCONJ
# , 	 PUNCT
# как 	 SCONJ
# всегда 	 ADV
# , 	 PUNCT
# ему 	 PRON
# захотелось 	 VERB
# заорать 	 VERB
# и 	 CCONJ
# высоко 	 ADV
# подпрыгнуть 	 VERB
# , 	 PUNCT
# и 	 CCONJ
# он 	 PRON
#
#  	 SPACE
# немедленно 	 ADV
# сделал 	 VERB
# это 	 PRON
# , 	 PUNCT
# и 	 CCONJ
# Антон 	 PROPN
# , 	 PUNCT
# смеясь 	 VERB
# , 	 PUNCT
# поглядел 	 VERB
# на 	 ADP
# него 	 PRON
# , 	 PUNCT
# и 	 CCONJ
# он 	 PRON
# увидел 	 VERB
# в 	 ADP
# глазах 	 NOUN
# Антона 	 PROPN
#
#  	 SPACE
# совершенное 	 ADJ
# понимание 	 NOUN
# . 	 PUNCT
# А 	 CCONJ
# Анка 	 PROPN
# вложила 	 VERB
# два 	 NUM
# пальца 	 NOUN
# в 	 ADP
# рот 	 NOUN
# и 	 CCONJ
# лихо 	 NOUN
# свистнула 	 VERB
# , 	 PUNCT
# и 	 CCONJ
# они 	 PRON
# вошли 	 VERB
# в 	 ADP
#
#  	 SPACE
# лес 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# Лес 	 NOUN
# был 	 AUX
# сосновый 	 ADJ
# и 	 CCONJ
# редкий 	 ADJ
# , 	 PUNCT
# ноги 	 NOUN
# скользили 	 VERB
# по 	 ADP
# опавшей 	 VERB
# хвое 	 ADJ
# . 	 PUNCT
# Косые 	 ADJ
# солнечные 	 ADJ
# лучи 	 NOUN
#
#  	 SPACE
# падали 	 VERB
# между 	 ADP
# прямых 	 ADJ
# стволов 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# земля 	 NOUN
# была 	 AUX
# вся 	 DET
# в 	 ADP
# золотых 	 ADJ
# пятнах 	 NOUN
# . 	 PUNCT
# Пахло 	 VERB
# смолой 	 ADJ
# , 	 PUNCT
# озером 	 NOUN
# и 	 CCONJ
#
#  	 SPACE
# земляникой 	 NOUN
# ; 	 PUNCT
# где 	 ADV
# - 	 ADV
# то 	 ADV
# в 	 ADP
# небе 	 NOUN
# верещали 	 VERB
# невидимые 	 ADJ
# пичужки 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# Анка 	 NOUN
# шла 	 VERB
# впереди 	 ADV
# , 	 PUNCT
# держа 	 VERB
# арбалет 	 NOUN
# под 	 ADP
# мышкой 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# время 	 NOUN
# от 	 ADP
# времени 	 NOUN
# нагибалась 	 VERB
# за 	 ADP
#
#  	 SPACE
# кровавыми 	 ADJ
# , 	 PUNCT
# будто 	 SCONJ
# лакированными 	 ADJ
# , 	 PUNCT
# ягодами 	 NOUN
# земляники 	 NOUN
# . 	 PUNCT
# Антон 	 PROPN
# шел 	 VERB
# следом 	 ADV
# с 	 ADP
# добрым 	 ADJ
# боевым 	 ADJ
#
#  	 SPACE
# устройством 	 NOUN
# маршала 	 NOUN
# Тоца 	 PROPN
# на 	 ADP
# плече 	 NOUN
# . 	 PUNCT
# Колчан 	 NOUN
# с 	 ADP
# добрыми 	 ADJ
# боевыми 	 ADJ
# стрелами 	 NOUN
# тяжко 	 NOUN
#
#  	 SPACE
# похлопывал 	 VERB
# его 	 PRON
# по 	 ADP
# заду 	 NOUN
# . 	 PUNCT
# Он 	 PRON
# шел 	 VERB
# и 	 CCONJ
# поглядывал 	 VERB
# на 	 ADP
# Анкину 	 PROPN
# шею 	 NOUN
# — 	 PUNCT
# загорелую 	 ADJ
# , 	 PUNCT
# почти 	 ADV
# черную 	 ADJ
# , 	 PUNCT
#
#  	 SPACE
# с 	 ADP
# выступающими 	 ADJ
# позвонками 	 NOUN
# . 	 PUNCT
# Иногда 	 ADV
# он 	 PRON
# озирался 	 VERB
# , 	 PUNCT
# ища 	 VERB
# Пашку 	 PROPN
# , 	 PUNCT
# но 	 CCONJ
# Пашки 	 NOUN
# не 	 PART
# было 	 AUX
# видно 	 ADV
# , 	 PUNCT
#
#  	 SPACE
# только 	 PART
# по 	 ADP
# временам 	 NOUN
# то 	 SCONJ
# справа 	 ADV
# , 	 PUNCT
# то 	 SCONJ
# слева 	 ADV
# вспыхивала 	 VERB
# на 	 ADP
# солнце 	 NOUN
# его 	 DET
# красная 	 ADJ
# повязка 	 NOUN
# . 	 PUNCT
# Антон 	 PROPN
#
#  	 SPACE
# представил 	 VERB
# себе 	 PRON
# , 	 PUNCT
# как 	 SCONJ
# Пашка 	 PROPN
# бесшумно 	 ADV
# скользит 	 VERB
# между 	 ADP
# соснами 	 NOUN
# с 	 ADP
# карабином 	 NOUN
# наготове 	 PROPN
# , 	 PUNCT
#
#  	 SPACE
# вытянув 	 VERB
# вперед 	 ADV
# хищное 	 ADJ
# худое 	 ADJ
# лицо 	 NOUN
# с 	 ADP
# облупленным 	 ADJ
# носом 	 NOUN
# . 	 PUNCT
# Пашка 	 NOUN
# крался 	 VERB
# по 	 ADP
# сайве 	 NOUN
# , 	 PUNCT
# а 	 CCONJ
# сайва 	 ADV
# не 	 PART
#
#  	 SPACE
# шутит 	 VERB
# . 	 PUNCT
# Сайва 	 PROPN
# , 	 PUNCT
# приятель 	 NOUN
# , 	 PUNCT
# спросит 	 VERB
# — 	 PUNCT
# и 	 CCONJ
# надо 	 ADV
# успеть 	 VERB
# ответить 	 VERB
# , 	 PUNCT
# подумал 	 VERB
# Антон 	 PROPN
# и 	 CCONJ
# пригнулся 	 VERB
#
#  	 SPACE
# было 	 AUX
# , 	 PUNCT
# но 	 CCONJ
# впереди 	 ADV
# была 	 AUX
# Анка 	 PROPN
# , 	 PUNCT
# и 	 CCONJ
# она 	 PRON
# могла 	 VERB
# оглянуться 	 VERB
# . 	 PUNCT
# Получилось 	 VERB
# бы 	 AUX
# нелепо 	 ADV
# . 	 PUNCT
#
#        	 SPACE
# Анка 	 NOUN
# оглянулась 	 VERB
# и 	 CCONJ
# спросила 	 VERB
# : 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Вы 	 PRON
# ушли 	 VERB
# тихо 	 ADV
# ? 	 PUNCT
#
#        	 SPACE
# Антон 	 PROPN
# пожал 	 VERB
# плечами 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Кто 	 PRON
# же 	 PART
# уходит 	 VERB
# громко 	 ADV
# ? 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Я 	 PRON
# , 	 PUNCT
# кажется 	 VERB
# , 	 PUNCT
# все 	 PART
# - 	 PART
# таки 	 PART
# нашумела 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# озабоченно 	 ADV
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Я 	 PRON
# уронила 	 VERB
# таз 	 NOUN
# — 	 PUNCT
# и 	 CCONJ
#
#  	 SPACE
# вдруг 	 ADV
# в 	 ADP
# коридоре 	 NOUN
# шаги 	 NOUN
# . 	 PUNCT
# Наверное 	 ADV
# , 	 PUNCT
# Дева 	 PROPN
# Катя 	 PROPN
# — 	 PUNCT
# она 	 PRON
# сегодня 	 ADV
# в 	 ADP
# дежурных 	 ADJ
# . 	 PUNCT
# Пришлось 	 VERB
# прыгать 	 VERB
#
#  	 SPACE
# в 	 ADP
# клумбу 	 NOUN
# . 	 PUNCT
# Как 	 SCONJ
# ты 	 PRON
# думаешь 	 VERB
# , 	 PUNCT
# Тошка 	 PROPN
# , 	 PUNCT
# что 	 SCONJ
# за 	 ADP
# цветы 	 NOUN
# растут 	 VERB
# на 	 ADP
# этой 	 DET
# клумбе 	 NOUN
# ? 	 PUNCT
#
#        	 SPACE
# Антон 	 PROPN
# сморщил 	 VERB
# лоб 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# У 	 ADP
# тебя 	 PRON
# под 	 ADP
# окном 	 NOUN
# ? 	 PUNCT
# Не 	 PART
# знаю 	 VERB
# . 	 PUNCT
# А 	 CCONJ
# что 	 PRON
# ? 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Очень 	 ADV
# упорные 	 ADJ
# цветы 	 NOUN
# . 	 PUNCT
# « 	 PUNCT
# Не 	 PART
# гнет 	 VERB
# их 	 DET
# ветер 	 NOUN
# , 	 PUNCT
# не 	 PART
# валит 	 VERB
# буря 	 NOUN
# » 	 PUNCT
# . 	 PUNCT
# В 	 ADP
# них 	 PRON
# прыгают 	 VERB
# несколько 	 NUM
#
#  	 SPACE
# лет 	 NOUN
# , 	 PUNCT
# а 	 CCONJ
# им 	 PRON
# хоть 	 ADV
# бы 	 AUX
# что 	 PRON
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Интересно 	 ADJ
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# глубокомысленно 	 ADV
# . 	 PUNCT
# Он 	 PRON
# вспомнил 	 VERB
# , 	 PUNCT
# что 	 SCONJ
# под 	 ADP
# его 	 DET
# окном 	 NOUN
#
#  	 SPACE
# тоже 	 ADV
# клумба 	 NOUN
# с 	 ADP
# цветами 	 NOUN
# , 	 PUNCT
# которые 	 PRON
# « 	 PUNCT
# не 	 PART
# гнет 	 VERB
# ветер 	 NOUN
# и 	 CCONJ
# не 	 PART
# валит 	 VERB
# буря 	 NOUN
# » 	 PUNCT
# . 	 PUNCT
# Но 	 CCONJ
# он 	 PRON
# никогда 	 ADV
# не 	 PART
# обращал 	 VERB
#
#  	 SPACE
# на 	 ADP
# это 	 PRON
# внимания 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# Анка 	 NOUN
# остановилась 	 VERB
# , 	 PUNCT
# подождала 	 VERB
# его 	 PRON
# и 	 CCONJ
# протянула 	 VERB
# горсть 	 NOUN
# земляники 	 NOUN
# . 	 PUNCT
# Антон 	 PROPN
# аккуратно 	 ADV
#
#  	 SPACE
# взял 	 VERB
# три 	 NUM
# ягоды 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Бери 	 PROPN
# еще 	 ADV
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Спасибо 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Я 	 PRON
# люблю 	 VERB
# собирать 	 VERB
# по 	 ADP
# одной 	 NUM
# . 	 PUNCT
# А 	 CCONJ
# Дева 	 PROPN
# Катя 	 PROPN
# вообще 	 ADV
#
#  	 SPACE
# ничего 	 PRON
# , 	 PUNCT
# верно 	 ADV
# ? 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Это 	 PART
# кому 	 PRON
# как 	 SCONJ
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Когда 	 SCONJ
# человеку 	 NOUN
# каждый 	 DET
# вечер 	 NOUN
# заявляют 	 VERB
# , 	 PUNCT
# что 	 SCONJ
# у 	 ADP
# него 	 PRON
#
#  	 SPACE
# ноги 	 NOUN
# то 	 PRON
# в 	 ADP
# грязи 	 NOUN
# , 	 PUNCT
# то 	 SCONJ
# в 	 ADP
# пыли 	 NOUN
# … 	 PUNCT
#
#        	 SPACE
# Она 	 PRON
# замолчала 	 VERB
# . 	 PUNCT
# Было 	 AUX
# удивительно 	 ADJ
# хорошо 	 ADJ
# идти 	 VERB
# с 	 ADP
# нею 	 PROPN
# по 	 ADP
# лесу 	 NOUN
# плечом 	 NOUN
# к 	 ADP
# плечу 	 NOUN
# вдвоем 	 ADV
# , 	 PUNCT
#
#  	 SPACE
# касаясь 	 VERB
# голыми 	 ADJ
# локтями 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# поглядывать 	 VERB
# на 	 ADP
# нее 	 PRON
# — 	 PUNCT
# какая 	 DET
# она 	 PRON
# красивая 	 ADJ
# , 	 PUNCT
# ловкая 	 ADJ
# и 	 CCONJ
# необычно 	 ADV
#
#  	 SPACE
# доброжелательная 	 ADJ
# и 	 CCONJ
# какие 	 DET
# у 	 ADP
# нее 	 PRON
# большие 	 ADJ
# серые 	 ADJ
# глаза 	 NOUN
# с 	 ADP
# черными 	 ADJ
# ресницами 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Да 	 PART
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# , 	 PUNCT
# протягивая 	 VERB
# руку 	 NOUN
# , 	 PUNCT
# чтобы 	 SCONJ
# снять 	 VERB
# блеснувшую 	 ADJ
# на 	 ADP
# солнце 	 NOUN
#
#  	 SPACE
# паутину 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Уж 	 PART
# у 	 ADP
# нее 	 PRON
# - 	 VERB
# то 	 NOUN
# ноги 	 NOUN
# не 	 PART
# пыльные 	 VERB
# . 	 PUNCT
# Если 	 SCONJ
# тебя 	 PRON
# через 	 ADP
# лужи 	 NOUN
# носят 	 VERB
# на 	 ADP
# руках 	 NOUN
# , 	 PUNCT
# тогда 	 ADV
# , 	 PUNCT
#
#  	 SPACE
# понимаешь 	 VERB
# , 	 PUNCT
# не 	 PART
# запылишься 	 VERB
# … 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Кто 	 PRON
# это 	 PRON
# ее 	 PRON
# носит 	 VERB
# ? 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Генрих 	 PROPN
# с 	 ADP
# метеостанции 	 NOUN
# . 	 PUNCT
# Знаешь 	 VERB
# , 	 PUNCT
# здоровый 	 ADJ
# такой 	 DET
# , 	 PUNCT
# с 	 ADP
# белыми 	 ADJ
# волосами 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Правда 	 ADV
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# чего 	 PRON
# такого 	 DET
# ? 	 PUNCT
# Каждый 	 DET
# малек 	 NOUN
# знает 	 VERB
# , 	 PUNCT
# что 	 SCONJ
# они 	 PRON
# влюблены 	 ADJ
# . 	 PUNCT
#
#       	 SPACE
# Они 	 PRON
# опять 	 ADV
# замолчали 	 VERB
# . 	 PUNCT
# Антон 	 PROPN
# глянул 	 VERB
# на 	 ADP
# Анку 	 PROPN
# . 	 PUNCT
# Глаза 	 NOUN
# у 	 ADP
# Анки 	 PROPN
# были 	 VERB
# как 	 SCONJ
# черные 	 ADJ
# щелочки 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# когда 	 SCONJ
# это 	 PRON
# было 	 AUX
# ? 	 PUNCT
# — 	 PUNCT
# спросила 	 VERB
# она 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Да 	 PART
# было 	 AUX
# в 	 ADP
# одну 	 NUM
# лунную 	 ADJ
# ночь 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# ответил 	 VERB
# Антон 	 PROPN
# без 	 ADP
# всякой 	 DET
# охоты 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Только 	 PART
# ты 	 PRON
#
#  	 SPACE
# смотри 	 VERB
# не 	 PART
# разболтай 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# Анка 	 NOUN
# усмехнулась 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Никто 	 PRON
# тебя 	 PRON
# за 	 ADP
# язык 	 NOUN
# не 	 PART
# тянул 	 VERB
# , 	 PUNCT
# Тошка 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# она 	 PRON
# . 	 PUNCT
# — 	 PUNCT
# Хочешь 	 VERB
# земляники 	 NOUN
# ? 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# машинально 	 ADV
# сгреб 	 NOUN
# ягоды 	 NOUN
# с 	 ADP
# испачканной 	 ADJ
# ладошки 	 NOUN
# и 	 CCONJ
# сунул 	 VERB
# в 	 ADP
# рот 	 NOUN
# . 	 PUNCT
# Не 	 PART
# люблю 	 VERB
#
#  	 SPACE
# болтунов 	 NOUN
# , 	 PUNCT
# подумал 	 VERB
# он 	 PRON
# . 	 PUNCT
# Терпеть 	 VERB
# не 	 PART
# могу 	 VERB
# трепачей 	 NOUN
# . 	 PUNCT
# Он 	 PRON
# вдруг 	 ADV
# нашел 	 VERB
# аргумент 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Тебя 	 PRON
# тоже 	 ADV
# когда 	 ADV
# - 	 ADV
# нибудь 	 ADV
# будут 	 AUX
# таскать 	 VERB
# на 	 ADP
# руках 	 NOUN
# . 	 PUNCT
# Тебе 	 PRON
# приятно 	 ADJ
# будет 	 AUX
# , 	 PUNCT
# если 	 SCONJ
# начнут 	 VERB
# об 	 ADP
#
#  	 SPACE
# этом 	 PRON
# болтать 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Откуда 	 ADV
# ты 	 PRON
# взял 	 VERB
# , 	 PUNCT
# что 	 SCONJ
# я 	 PRON
# собираюсь 	 VERB
# болтать 	 VERB
# ? 	 PUNCT
# — 	 PUNCT
# рассеянно 	 ADV
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Я 	 PRON
# вообще 	 ADV
# не 	 PART
# люблю 	 VERB
# болтунов 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Слушай 	 PROPN
# , 	 PUNCT
# что 	 PRON
# ты 	 PRON
# задумала 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ничего 	 PRON
# особенного 	 ADJ
# . 	 PUNCT
# — 	 PUNCT
# Анка 	 PROPN
# пожала 	 VERB
# плечами 	 NOUN
# . 	 PUNCT
# Немного 	 ADV
# погодя 	 VERB
# она 	 PRON
# доверительно 	 ADV
#
#  	 SPACE
# сообщила 	 VERB
# : 	 PUNCT
# — 	 PUNCT
# Знаешь 	 VERB
# , 	 PUNCT
# мне 	 PRON
# ужасно 	 ADV
# надоело 	 VERB
# каждый 	 DET
# божий 	 ADJ
# вечер 	 NOUN
# дважды 	 ADV
# мыть 	 VERB
# ноги 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Бедная 	 ADJ
# Дева 	 PROPN
# Катя 	 PROPN
# , 	 PUNCT
# подумал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# Это 	 PRON
# тебе 	 PRON
# не 	 PART
# сайва 	 ADJ
# . 	 PUNCT
#
#       	 SPACE
# Они 	 PRON
# вышли 	 VERB
# на 	 ADP
# тропинку 	 NOUN
# . 	 PUNCT
# Тропинка 	 NOUN
# вела 	 VERB
# вниз 	 ADV
# , 	 PUNCT
# и 	 CCONJ
# лес 	 NOUN
# становился 	 VERB
# все 	 PART
# темнее 	 ADJ
# и 	 CCONJ
# темнее 	 ADJ
# . 	 PUNCT
#
#  	 SPACE
# Здесь 	 ADV
# буйно 	 ADV
# росли 	 VERB
# папоротник 	 NOUN
# и 	 CCONJ
# высокая 	 ADJ
# сырая 	 ADJ
# трава 	 NOUN
# . 	 PUNCT
# Стволы 	 NOUN
# сосен 	 NOUN
# были 	 AUX
# покрыты 	 VERB
# мхом 	 NOUN
# и 	 CCONJ
#
#  	 SPACE
# белой 	 ADJ
# пеной 	 NOUN
# лишайников 	 NOUN
# . 	 PUNCT
# Но 	 CCONJ
# сайва 	 ADV
# не 	 PART
# шутит 	 VERB
# . 	 PUNCT
# Хриплый 	 ADJ
# голос 	 NOUN
# , 	 PUNCT
# в 	 ADP
# котором 	 PRON
# не 	 PART
# было 	 VERB
# ничего 	 PRON
#
#  	 SPACE
# человеческого 	 ADJ
# , 	 PUNCT
# неожиданно 	 ADV
# проревел 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Стой 	 PROPN
# ! 	 PUNCT
# Бросай 	 ADV
# оружие 	 NOUN
# — 	 PUNCT
# ты 	 PRON
# , 	 PUNCT
# благородный 	 ADJ
# дон 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# ты 	 PRON
# , 	 PUNCT
# дона 	 NOUN
# ! 	 PUNCT
#
#       	 SPACE
# Когда 	 SCONJ
# сайва 	 ADV
# спрашивает 	 VERB
# , 	 PUNCT
# надо 	 ADV
# успеть 	 VERB
# ответить 	 VERB
# . 	 PUNCT
# Точным 	 ADJ
# движением 	 NOUN
# Антон 	 PROPN
# сшиб 	 VERB
# Анку 	 PROPN
# в 	 ADP
#
#  	 SPACE
# папоротники 	 NOUN
# налево 	 ADV
# , 	 PUNCT
# а 	 CCONJ
# сам 	 ADJ
# прыгнул 	 VERB
# в 	 ADP
# папоротники 	 NOUN
# направо 	 ADV
# , 	 PUNCT
# покатился 	 VERB
# и 	 CCONJ
# залег 	 VERB
# за 	 ADP
# гнилым 	 ADJ
#
#  	 SPACE
# пнем 	 NOUN
# . 	 PUNCT
# Хриплое 	 ADJ
# эхо 	 NOUN
# еще 	 ADV
# отдавалось 	 VERB
# в 	 ADP
# стволах 	 NOUN
# сосен 	 NOUN
# , 	 PUNCT
# а 	 CCONJ
# тропинка 	 NOUN
# была 	 AUX
# уже 	 ADV
# пуста 	 ADJ
# . 	 PUNCT
# Наступила 	 VERB
#
#  	 SPACE
# тишина 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# , 	 PUNCT
# завалившись 	 VERB
# на 	 ADP
# бок 	 NOUN
# , 	 PUNCT
# вертел 	 VERB
# колесико 	 PROPN
# , 	 PUNCT
# натягивая 	 VERB
# тетиву 	 NOUN
# . 	 PUNCT
# Хлопнул 	 VERB
# выстрел 	 NOUN
# , 	 PUNCT
# на 	 ADP
#
#  	 SPACE
# Антона 	 PROPN
# посыпался 	 VERB
# какой 	 DET
# - 	 DET
# то 	 DET
# мусор 	 NOUN
# . 	 PUNCT
# Хриплый 	 ADJ
# нечеловеческий 	 ADJ
# голос 	 NOUN
# сообщил 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Дон 	 PROPN
# поражен 	 VERB
# в 	 ADP
# пятку 	 NOUN
# ! 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# застонал 	 VERB
# и 	 CCONJ
# подтянул 	 VERB
# ногу 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Да 	 CCONJ
# не 	 PART
# в 	 ADP
# эту 	 DET
# , 	 PUNCT
# в 	 ADP
# правую 	 ADJ
# , 	 PUNCT
# — 	 PUNCT
# поправил 	 VERB
# голос 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Было 	 AUX
# слышно 	 ADJ
# , 	 PUNCT
# как 	 SCONJ
# Пашка 	 PROPN
# хихикает 	 VERB
# . 	 PUNCT
# Антон 	 PROPN
# осторожно 	 ADV
# выглянул 	 VERB
# из 	 ADP
# - 	 ADP
# за 	 ADP
# пня 	 NOUN
# , 	 PUNCT
# но 	 CCONJ
# ничего 	 PRON
# не 	 PART
#
#  	 SPACE
# было 	 AUX
# видно 	 ADJ
# в 	 ADP
# сумеречной 	 ADJ
# зеленой 	 ADJ
# каше 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# В 	 ADP
# этот 	 DET
# момент 	 NOUN
# раздался 	 VERB
# пронзительный 	 ADJ
# свист 	 NOUN
# и 	 CCONJ
# шум 	 NOUN
# , 	 PUNCT
# как 	 SCONJ
# будто 	 PART
# упало 	 VERB
# дерево 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Уау 	 PROPN
# ! 	 PUNCT
# .. 	 PUNCT
# — 	 PUNCT
# сдавленно 	 ADV
# заорал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Пощады 	 NOUN
# ! 	 PUNCT
# Пощады 	 NOUN
# ! 	 PUNCT
# Не 	 PART
# убивайте 	 VERB
# меня 	 PRON
# ! 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# сразу 	 ADV
# вскочил 	 VERB
# . 	 PUNCT
# Навстречу 	 ADV
# ему 	 PRON
# из 	 ADP
# папоротников 	 NOUN
# , 	 PUNCT
# пятясь 	 VERB
# , 	 PUNCT
# вылез 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# Руки 	 NOUN
# его 	 PRON
#
#  	 SPACE
# были 	 AUX
# подняты 	 VERB
# над 	 ADP
# головой 	 NOUN
# . 	 PUNCT
# Голос 	 NOUN
# Анки 	 PROPN
# спросил 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Тошка 	 NOUN
# , 	 PUNCT
# ты 	 PRON
# видишь 	 VERB
# его 	 PRON
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Как 	 SCONJ
# на 	 ADP
# ладони 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# одобрительно 	 ADV
# отозвался 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Не 	 PART
# поворачиваться 	 VERB
# ! 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# крикнул 	 VERB
# он 	 PRON
# Пашке 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Руки 	 NOUN
# за 	 ADP
# голову 	 NOUN
# ! 	 PUNCT
#
#       	 SPACE
# Пашка 	 NOUN
# покорно 	 ADV
# заложил 	 VERB
# руки 	 NOUN
# за 	 ADP
# голову 	 NOUN
# и 	 CCONJ
# объявил 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Я 	 PRON
# ничего 	 PRON
# не 	 PART
# скажу 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Что 	 PRON
# полагается 	 VERB
# с 	 ADP
# ним 	 PRON
# делать 	 VERB
# , 	 PUNCT
# Тошка 	 PROPN
# ? 	 PUNCT
# — 	 PUNCT
# спросила 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Сейчас 	 ADV
# увидишь 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# и 	 CCONJ
# удобно 	 ADV
# уселся 	 VERB
# на 	 ADP
# пень 	 NOUN
# , 	 PUNCT
# положив 	 VERB
# арбалет 	 NOUN
# на 	 ADP
#
#  	 SPACE
# колени 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Имя 	 NOUN
# ! 	 PUNCT
# — 	 PUNCT
# рявкнул 	 VERB
# он 	 PRON
# голосом 	 NOUN
# Гексы 	 PROPN
# Ируканского 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# Пашка 	 NOUN
# изобразил 	 VERB
# спиной 	 NOUN
# презрение 	 NOUN
# и 	 CCONJ
# неповиновение 	 NOUN
# . 	 PUNCT
# Антон 	 PROPN
# выстрелил 	 VERB
# . 	 PUNCT
# Тяжелая 	 ADJ
#
#  	 SPACE
# стрела 	 NOUN
# с 	 ADP
# треском 	 NOUN
# вонзилась 	 VERB
# в 	 ADP
# ветку 	 NOUN
# над 	 ADP
# Пашкиной 	 ADJ
# головой 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ого 	 INTJ
# ! 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# голос 	 NOUN
# Анки 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Меня 	 PRON
# зовут 	 VERB
# Бон 	 PROPN
# Саранча 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# неохотно 	 ADV
# признался 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# « 	 PUNCT
# И 	 CCONJ
# здесь 	 ADV
# он 	 PRON
# , 	 PUNCT
#
#  	 SPACE
# по 	 ADV
# - 	 ADV
# видимому 	 ADV
# , 	 PUNCT
# лжет 	 VERB
# — 	 PUNCT
# один 	 NUM
# из 	 ADP
# тех 	 DET
# , 	 PUNCT
# кто 	 PRON
# были 	 AUX
# с 	 ADP
# ним 	 PRON
# » 	 PUNCT
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Известный 	 ADJ
# насильник 	 NOUN
# и 	 CCONJ
# убийца 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# пояснил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Но 	 CCONJ
# он 	 PRON
# никогда 	 ADV
# ничего 	 PRON
# не 	 PART
#
#  	 SPACE
# делает 	 VERB
# даром 	 NOUN
# . 	 PUNCT
# Кто 	 PRON
# послал 	 VERB
# тебя 	 PRON
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Меня 	 PRON
# послал 	 VERB
# дон 	 PROPN
# Сатарина 	 PROPN
# Беспощадный 	 ADJ
# , 	 PUNCT
# — 	 PUNCT
# соврал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# презрительно 	 ADV
# сказал 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Вот 	 PART
# эта 	 DET
# рука 	 NOUN
# оборвала 	 VERB
# нить 	 NOUN
# зловонной 	 VERB
# жизни 	 NOUN
# дона 	 NOUN
# Сатарины 	 PROPN
# два 	 NUM
# года 	 NOUN
# назад 	 ADV
# в 	 ADP
#
#  	 SPACE
# Урочище 	 PROPN
# Тяжелых 	 ADJ
# Мечей 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Давай 	 VERB
# я 	 PRON
# всажу 	 VERB
# в 	 ADP
# него 	 PRON
# стрелу 	 NOUN
# ? 	 PUNCT
# — 	 PUNCT
# предложила 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Я 	 PRON
# совершенно 	 ADV
# забыл 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# поспешно 	 ADV
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# В 	 ADP
# действительности 	 NOUN
# меня 	 PRON
#
#  	 SPACE
# послал 	 VERB
# Арата 	 PROPN
# Красивый 	 PROPN
# . 	 PUNCT
# Он 	 PRON
# обещал 	 VERB
# мне 	 PRON
# сто 	 NUM
# золотых 	 ADJ
# за 	 ADP
# ваши 	 DET
# головы 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# хлопнул 	 VERB
# себя 	 PRON
# по 	 ADP
# коленям 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Вот 	 PART
# брехун 	 NOUN
# ! 	 PUNCT
# — 	 PUNCT
# вскричал 	 VERB
# он 	 PRON
# . 	 PUNCT
# — 	 PUNCT
# Да 	 PART
# разве 	 PART
# станет 	 VERB
# Арата 	 PROPN
# связываться 	 VERB
# с 	 ADP
# таким 	 DET
# негодяем 	 VERB
# , 	 PUNCT
#
#  	 SPACE
# как 	 SCONJ
# ты 	 PRON
# ! 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Можно 	 ADV
# я 	 PRON
# все 	 PART
# - 	 PART
# таки 	 PART
# всажу 	 VERB
# в 	 ADP
# него 	 PRON
# стрелу 	 NOUN
# ? 	 PUNCT
# — 	 PUNCT
# кровожадно 	 ADV
# спросила 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# демонически 	 ADV
# захохотал 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Между 	 ADP
# прочим 	 ADJ
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# у 	 ADP
# тебя 	 PRON
# отстрелена 	 VERB
# правая 	 ADJ
# пятка 	 NOUN
# . 	 PUNCT
# Пора 	 NOUN
# бы 	 AUX
# тебе 	 PRON
#
#  	 SPACE
# истечь 	 VERB
# кровью 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Дудки 	 PROPN
# ! 	 PUNCT
# — 	 PUNCT
# возразил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Во 	 ADV
# - 	 ADV
# первых 	 ADV
# , 	 PUNCT
# я 	 PRON
# все 	 DET
# время 	 NOUN
# жую 	 VERB
# кору 	 NOUN
# белого 	 ADJ
# дерева 	 NOUN
# , 	 PUNCT
# а 	 CCONJ
#
#  	 SPACE
# во 	 ADV
# - 	 ADV
# вторых 	 ADV
# , 	 PUNCT
# две 	 NUM
# прекрасные 	 ADJ
# варварки 	 NOUN
# уже 	 ADV
# перевязали 	 VERB
# мне 	 PRON
# раны 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Папоротники 	 NOUN
# зашевелились 	 VERB
# , 	 PUNCT
# и 	 CCONJ
# Анка 	 PROPN
# вышла 	 VERB
# на 	 ADP
# тропинку 	 NOUN
# . 	 PUNCT
# На 	 ADP
# щеке 	 NOUN
# ее 	 PRON
# была 	 AUX
# царапина 	 NOUN
# , 	 PUNCT
#
#  	 SPACE
# колени 	 NOUN
# были 	 AUX
# вымазаны 	 VERB
# в 	 ADP
# земле 	 NOUN
# и 	 CCONJ
# зелени 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Пора 	 NOUN
# бросить 	 VERB
# его 	 PRON
# в 	 ADP
# болото 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# объявила 	 VERB
# она 	 PRON
# . 	 PUNCT
# — 	 PUNCT
# Когда 	 SCONJ
# враг 	 NOUN
# не 	 PART
# сдается 	 VERB
# , 	 PUNCT
# его 	 PRON
#
#  	 SPACE
# уничтожают 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# Пашка 	 PROPN
# опустил 	 VERB
# руки 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Вообще 	 ADV
# - 	 ADV
# то 	 ADV
# ты 	 PRON
# играешь 	 VERB
# не 	 PART
# по 	 ADP
# правилам 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# он 	 PRON
# Антону 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# У 	 ADP
# тебя 	 PRON
# все 	 DET
# время 	 NOUN
#
#  	 SPACE
# получается 	 VERB
# , 	 PUNCT
# что 	 SCONJ
# Гекса 	 PROPN
# хороший 	 ADJ
# человек 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Много 	 ADV
# ты 	 PRON
# знаешь 	 VERB
# ! 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# и 	 CCONJ
# тоже 	 ADV
# вышел 	 VERB
# на 	 ADP
# тропинку 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Сайва 	 PROPN
# не 	 PART
# шутит 	 VERB
# , 	 PUNCT
#
#  	 SPACE
# грязный 	 ADJ
# наемник 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Анка 	 NOUN
# вернула 	 VERB
# Пашке 	 PROPN
# карабин 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Вы 	 PRON
# что 	 PRON
# , 	 PUNCT
# всегда 	 ADV
# так 	 ADV
# палите 	 VERB
# друг 	 PRON
# в 	 ADP
# друга 	 PRON
# ? 	 PUNCT
# — 	 PUNCT
# спросила 	 VERB
# она 	 PRON
# с 	 ADP
# завистью 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# как 	 ADV
# же 	 PART
# ! 	 PUNCT
# — 	 PUNCT
# удивился 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Что 	 PRON
# , 	 PUNCT
# нам 	 PRON
# кричать 	 VERB
# : 	 PUNCT
# « 	 PUNCT
# Кх 	 PROPN
# - 	 PROPN
# кх 	 INTJ
# ! 	 PUNCT
# Пу 	 NOUN
# - 	 NOUN
# пу 	 INTJ
# ! 	 PUNCT
# » 	 PUNCT
# — 	 PUNCT
# что 	 PRON
# ли 	 PART
# ? 	 PUNCT
# В 	 ADP
#
#  	 SPACE
# игре 	 NOUN
# нужен 	 ADJ
# элемент 	 NOUN
# риска 	 NOUN
# ! 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# небрежно 	 ADV
# сказал 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Например 	 ADV
# , 	 PUNCT
# мы 	 PRON
# часто 	 ADV
# играем 	 VERB
# в 	 ADP
# Вильгельма 	 PROPN
# Телля 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# По 	 ADP
# очереди 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# подхватил 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Сегодня 	 ADV
# я 	 PRON
# стою 	 VERB
# с 	 ADP
# яблоком 	 NOUN
# , 	 PUNCT
# а 	 CCONJ
# завтра 	 ADV
# он 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# Анка 	 NOUN
# оглядела 	 VERB
# их 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Вот 	 PART
# как 	 ADV
# ? 	 PUNCT
# — 	 PUNCT
# медленно 	 ADV
# сказала 	 VERB
# она 	 PRON
# . 	 PUNCT
# — 	 PUNCT
# Интересно 	 ADJ
# было 	 AUX
# бы 	 AUX
# посмотреть 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Мы 	 PRON
# бы 	 AUX
# с 	 ADP
# удовольствием 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# ехидно 	 ADV
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Яблока 	 PROPN
# вот 	 PART
# нет 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# Пашка 	 NOUN
# широко 	 ADV
# ухмылялся 	 VERB
# . 	 PUNCT
# Тогда 	 ADV
# Анка 	 PROPN
# сорвала 	 VERB
# у 	 ADP
# него 	 PRON
# с 	 ADP
# головы 	 NOUN
# пиратскую 	 ADJ
# повязку 	 NOUN
# и 	 CCONJ
#
#  	 SPACE
# быстро 	 ADV
# свернула 	 VERB
# из 	 ADP
# нее 	 PRON
# длинный 	 ADJ
# кулек 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Яблоко 	 NOUN
# — 	 PUNCT
# это 	 PART
# условность 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# она 	 PRON
# . 	 PUNCT
# — 	 PUNCT
# Вот 	 PART
# отличная 	 ADJ
# мишень 	 NOUN
# . 	 PUNCT
# Сыграем 	 VERB
# в 	 ADP
#
#  	 SPACE
# Вильгельма 	 PROPN
# Телля 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# взял 	 VERB
# красный 	 ADJ
# кулек 	 NOUN
# и 	 CCONJ
# внимательно 	 ADV
# осмотрел 	 VERB
# его 	 PRON
# . 	 PUNCT
# Он 	 PRON
# взглянул 	 VERB
# на 	 ADP
# Анку 	 PROPN
# — 	 PUNCT
# глаза 	 NOUN
# у 	 ADP
#
#  	 SPACE
# нее 	 PRON
# были 	 AUX
# как 	 SCONJ
# щелочки 	 NOUN
# . 	 PUNCT
# А 	 CCONJ
# Пашка 	 PROPN
# развлекался 	 VERB
# — 	 PUNCT
# ему 	 PRON
# было 	 AUX
# весело 	 ADJ
# . 	 PUNCT
# Антон 	 PROPN
# протянул 	 VERB
# ему 	 PRON
# кулек 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# « 	 PUNCT
# В 	 ADP
# тридцати 	 NUM
# шагах 	 NOUN
# промаха 	 NOUN
# в 	 ADP
# карту 	 NOUN
# не 	 PART
# дам 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# ровным 	 ADJ
# голосом 	 NOUN
# сказал 	 VERB
# он 	 PRON
# . 	 PUNCT
# — 	 PUNCT
#
#  	 SPACE
# Разумеется 	 VERB
# , 	 PUNCT
# из 	 ADP
# знакомых 	 ADJ
# пистолетов 	 NOUN
# » 	 PUNCT
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# « 	 PUNCT
# Право 	 NOUN
# ? 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# и 	 CCONJ
# обратилась 	 VERB
# к 	 ADP
# Пашке 	 PROPN
# : 	 PUNCT
# — 	 PUNCT
# А 	 CCONJ
# ты 	 PRON
# , 	 PUNCT
# мой 	 DET
# друг 	 NOUN
# , 	 PUNCT
# попадешь 	 VERB
# ли 	 PART
# в 	 ADP
#
#  	 SPACE
# карту 	 NOUN
# на 	 ADP
# тридцати 	 NUM
# шагах 	 NOUN
# ? 	 PUNCT
# » 	 PUNCT
#
#       	 SPACE
# Пашка 	 PROPN
# пристраивал 	 VERB
# колпак 	 NOUN
# на 	 ADP
# голове 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# « 	 PUNCT
# Когда 	 ADV
# - 	 ADV
# нибудь 	 ADV
# мы 	 PRON
# попробуем 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# он 	 PRON
# , 	 PUNCT
# скаля 	 NOUN
# зубы 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# В 	 ADP
# свое 	 DET
# время 	 NOUN
# я 	 PRON
# стрелял 	 VERB
# не 	 PART
#
#  	 SPACE
# худо 	 NOUN
# » 	 PUNCT
# . 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# повернулся 	 VERB
# и 	 CCONJ
# пошел 	 VERB
# по 	 ADP
# тропинке 	 NOUN
# , 	 PUNCT
# вслух 	 ADV
# считая 	 VERB
# шаги 	 NOUN
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Пятнадцать 	 NUM
# … 	 PUNCT
# шестнадцать 	 VERB
# … 	 PUNCT
# семнадцать 	 VERB
# … 	 PUNCT
#
#       	 SPACE
# Пашка 	 NOUN
# что 	 PRON
# - 	 PRON
# то 	 PRON
# сказал 	 VERB
# — 	 PUNCT
# Антон 	 PROPN
# не 	 PART
# расслышал 	 VERB
# , 	 PUNCT
# и 	 CCONJ
# Анка 	 PROPN
# громко 	 ADV
# рассмеялась 	 VERB
# . 	 PUNCT
# Как 	 ADV
# - 	 ADV
# то 	 ADV
#
#  	 SPACE
# слишком 	 ADV
# громко 	 ADV
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Тридцать 	 NUM
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# и 	 CCONJ
# повернулся 	 VERB
# . 	 PUNCT
#
#        	 SPACE
# На 	 ADP
# тридцати 	 NUM
# шагах 	 NOUN
# Пашка 	 PROPN
# выглядел 	 VERB
# совсем 	 ADV
# маленьким 	 ADJ
# . 	 PUNCT
# Красный 	 ADJ
# треугольник 	 NOUN
# кулька 	 PROPN
#
#  	 SPACE
# торчал 	 VERB
# у 	 ADP
# него 	 PRON
# на 	 ADP
# голове 	 NOUN
# , 	 PUNCT
# как 	 SCONJ
# шутовской 	 ADJ
# колпак 	 NOUN
# . 	 PUNCT
# Пашка 	 NOUN
# ухмылялся 	 VERB
# . 	 PUNCT
# Он 	 PRON
# все 	 PART
# еще 	 ADV
# играл 	 VERB
# . 	 PUNCT
# Антон 	 PROPN
#
#  	 SPACE
# нагнулся 	 VERB
# и 	 CCONJ
# стал 	 VERB
# неторопливо 	 ADV
# натягивать 	 VERB
# тетиву 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Благословляю 	 VERB
# тебя 	 PRON
# , 	 PUNCT
# отец 	 NOUN
# мой 	 DET
# Вильгельм 	 PROPN
# ! 	 PUNCT
# — 	 PUNCT
# крикнул 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# И 	 CCONJ
# благодарю 	 VERB
# тебя 	 PRON
# за 	 ADP
#
#  	 SPACE
# все 	 PRON
# , 	 PUNCT
# что 	 PRON
# бы 	 AUX
# ни 	 PART
# случилось 	 VERB
# . 	 PUNCT
#
#        	 SPACE
# Антон 	 PROPN
# наложил 	 VERB
# стрелу 	 NOUN
# и 	 CCONJ
# выпрямился 	 VERB
# . 	 PUNCT
# Пашка 	 NOUN
# и 	 CCONJ
# Анка 	 PROPN
# смотрели 	 VERB
# на 	 ADP
# него 	 PRON
# . 	 PUNCT
# Они 	 PRON
# стояли 	 VERB
#
#  	 SPACE
# рядом 	 ADV
# . 	 PUNCT
# Тропинка 	 NOUN
# была 	 AUX
# как 	 SCONJ
# темный 	 ADJ
# сырой 	 ADJ
# коридор 	 NOUN
# между 	 ADP
# высоких 	 ADJ
# зеленых 	 ADJ
# стен 	 NOUN
# . 	 PUNCT
# Антон 	 PROPN
#
#  	 SPACE
# поднял 	 VERB
# арбалет 	 NOUN
# . 	 PUNCT
# Боевое 	 ADJ
# устройство 	 NOUN
# маршала 	 NOUN
# Тоца 	 PROPN
# стало 	 VERB
# необычайно 	 ADV
# тяжелым 	 ADJ
# . 	 PUNCT
# Руки 	 NOUN
# дрожат 	 VERB
# , 	 PUNCT
#
#  	 SPACE
# подумал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# Плохо 	 ADJ
# . 	 PUNCT
# Зря 	 PROPN
# . 	 PUNCT
# Он 	 PRON
# вспомнил 	 VERB
# , 	 PUNCT
# как 	 SCONJ
# зимой 	 NOUN
# они 	 PRON
# с 	 ADP
# Пашкой 	 PROPN
# целый 	 ADJ
# час 	 NOUN
# кидали 	 VERB
# снежки 	 NOUN
#
#  	 SPACE
# в 	 ADP
# чугунную 	 ADJ
# шишку 	 NOUN
# на 	 ADP
# столбе 	 NOUN
# ограды 	 NOUN
# . 	 PUNCT
# Кидали 	 VERB
# с 	 ADP
# двадцати 	 NUM
# шагов 	 NOUN
# , 	 PUNCT
# с 	 ADP
# пятнадцати 	 NUM
# и 	 CCONJ
# с 	 ADP
# десяти 	 NUM
# — 	 PUNCT
# и 	 CCONJ
#
#  	 SPACE
# никак 	 ADV
# не 	 PART
# могли 	 VERB
# попасть 	 VERB
# . 	 PUNCT
# А 	 CCONJ
# потом 	 ADV
# , 	 PUNCT
# когда 	 SCONJ
# уже 	 ADV
# надоело 	 VERB
# и 	 CCONJ
# они 	 PRON
# уходили 	 VERB
# , 	 PUNCT
# Пашка 	 PROPN
# небрежно 	 ADJ
# , 	 PUNCT
# не 	 PART
#
#  	 SPACE
# глядя 	 PROPN
# бросил 	 VERB
# последний 	 ADJ
# снежок 	 NOUN
# и 	 CCONJ
# попал 	 VERB
# . 	 PUNCT
# Антон 	 PROPN
# изо 	 ADP
# всех 	 DET
# сил 	 NOUN
# вдавил 	 VERB
# приклад 	 NOUN
# в 	 ADP
# плечо 	 NOUN
# . 	 PUNCT
# Анка 	 NOUN
#
#  	 SPACE
# стоит 	 VERB
# слишком 	 ADV
# близко 	 ADV
# , 	 PUNCT
# подумал 	 VERB
# он 	 PRON
# . 	 PUNCT
# Он 	 PRON
# хотел 	 VERB
# было 	 AUX
# крикнуть 	 VERB
# ей 	 PRON
# , 	 PUNCT
# чтобы 	 SCONJ
# она 	 PRON
# отошла 	 VERB
# , 	 PUNCT
# но 	 CCONJ
# понял 	 VERB
# , 	 PUNCT
#
#  	 SPACE
# что 	 SCONJ
# это 	 PRON
# было 	 AUX
# бы 	 AUX
# глупо 	 ADJ
# . 	 PUNCT
# Выше 	 ADJ
# . 	 PUNCT
# Еще 	 ADV
# выше 	 ADJ
# … 	 PUNCT
# Еще 	 ADV
# … 	 PUNCT
# Его 	 PRON
# вдруг 	 ADV
# охватила 	 VERB
# уверенность 	 NOUN
# , 	 PUNCT
# что 	 SCONJ
# , 	 PUNCT
# если 	 SCONJ
#
#  	 SPACE
# он 	 PRON
# даже 	 PART
# повернется 	 VERB
# к 	 ADP
# ним 	 PRON
# спиной 	 NOUN
# , 	 PUNCT
# фунтовая 	 ADJ
# стрела 	 NOUN
# все 	 ADV
# равно 	 ADJ
# вонзится 	 VERB
# точно 	 ADV
# в 	 ADP
# Пашкину 	 PROPN
#
#  	 SPACE
# переносицу 	 NOUN
# , 	 PUNCT
# между 	 ADP
# веселыми 	 ADJ
# зелеными 	 ADJ
# глазами 	 NOUN
# . 	 PUNCT
# Он 	 PRON
# открыл 	 VERB
# глаза 	 NOUN
# и 	 CCONJ
# посмотрел 	 VERB
# на 	 ADP
# Пашку 	 PROPN
# . 	 PUNCT
#
#  	 SPACE
# Пашка 	 NOUN
# больше 	 ADV
# не 	 PART
# ухмылялся 	 VERB
# . 	 PUNCT
# А 	 CCONJ
# Анка 	 PROPN
# медленно 	 ADV
# - 	 ADV
# медленно 	 ADV
# поднимала 	 VERB
# руку 	 NOUN
# с 	 ADP
#
#  	 SPACE
# растопыренными 	 ADJ
# пальцами 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# лицо 	 NOUN
# у 	 ADP
# нее 	 PRON
# было 	 AUX
# напряженное 	 ADJ
# и 	 CCONJ
# очень 	 ADV
# взрослое 	 ADJ
# . 	 PUNCT
# Тогда 	 ADV
# Антон 	 PROPN
#
#  	 SPACE
# поднял 	 VERB
# арбалет 	 NOUN
# еще 	 ADV
# выше 	 ADV
# и 	 CCONJ
# нажал 	 VERB
# на 	 ADP
# спусковой 	 ADJ
# крючок 	 NOUN
# . 	 PUNCT
# Он 	 PRON
# не 	 PART
# видел 	 VERB
# , 	 PUNCT
# куда 	 ADV
# ушла 	 VERB
# стрела 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Промазал 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# он 	 PRON
# очень 	 ADV
# громко 	 ADV
# . 	 PUNCT
#
#        	 SPACE
# Переступая 	 VERB
# на 	 ADP
# негнущихся 	 ADJ
# ногах 	 NOUN
# , 	 PUNCT
# он 	 PRON
# двинулся 	 VERB
# по 	 ADP
# тропинке 	 NOUN
# . 	 PUNCT
# Пашка 	 NOUN
# вытер 	 VERB
# красным 	 ADJ
#
#  	 SPACE
# кульком 	 ADJ
# лицо 	 NOUN
# , 	 PUNCT
# встряхнув 	 VERB
# , 	 PUNCT
# развернул 	 VERB
# его 	 PRON
# и 	 CCONJ
# стал 	 VERB
# повязывать 	 VERB
# голову 	 NOUN
# . 	 PUNCT
# Анка 	 NOUN
# нагнулась 	 VERB
# и 	 CCONJ
#
#  	 SPACE
# подобрала 	 VERB
# свой 	 DET
# арбалет 	 NOUN
# . 	 PUNCT
# Если 	 SCONJ
# она 	 PRON
# этой 	 DET
# штукой 	 NOUN
# трахнет 	 VERB
# меня 	 PRON
# по 	 ADP
# голове 	 NOUN
# , 	 PUNCT
# подумал 	 VERB
# Антон 	 PROPN
# , 	 PUNCT
# я 	 PRON
# ей 	 PRON
#
#  	 SPACE
# скажу 	 VERB
# спасибо 	 NOUN
# . 	 PUNCT
# Но 	 CCONJ
# Анка 	 PROPN
# даже 	 PART
# не 	 PART
# взглянула 	 VERB
# на 	 ADP
# него 	 PRON
# . 	 PUNCT
#
#        	 SPACE
# Она 	 PRON
# повернулась 	 VERB
# к 	 ADP
# Пашке 	 PROPN
# и 	 CCONJ
# спросила 	 VERB
# : 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Пошли 	 VERB
# ? 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Сейчас 	 ADV
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#        	 SPACE
# Он 	 PRON
# посмотрел 	 VERB
# на 	 ADP
# Антона 	 PROPN
# и 	 CCONJ
# молча 	 ADV
# постучал 	 VERB
# себя 	 PRON
# согнутым 	 ADJ
# пальцем 	 NOUN
# по 	 ADP
# лбу 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# ты 	 PRON
# уже 	 ADV
# испугался 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#        	 SPACE
# Пашка 	 NOUN
# еще 	 ADV
# раз 	 NOUN
# постучал 	 VERB
# себя 	 PRON
# пальцем 	 NOUN
# по 	 ADP
# лбу 	 NOUN
# и 	 CCONJ
# пошел 	 VERB
# за 	 ADP
# Анкой 	 PROPN
# . 	 PUNCT
# Антон 	 PROPN
# плелся 	 VERB
# следом 	 ADV
# и 	 CCONJ
#
#  	 SPACE
# старался 	 VERB
# подавить 	 VERB
# в 	 ADP
# себе 	 PRON
# сомнения 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# А 	 CCONJ
# что 	 PRON
# я 	 PRON
# , 	 PUNCT
# собственно 	 ADV
# , 	 PUNCT
# сделал 	 VERB
# , 	 PUNCT
# вяло 	 NOUN
# думал 	 VERB
# он 	 PRON
# . 	 PUNCT
# Чего 	 PRON
# они 	 PRON
# надулись 	 VERB
# ? 	 PUNCT
# Ну 	 PART
# Пашка 	 NOUN
# ладно 	 ADV
# , 	 PUNCT
# он 	 PRON
#
#  	 SPACE
# испугался 	 VERB
# . 	 PUNCT
# Только 	 PART
# еще 	 ADV
# неизвестно 	 ADJ
# , 	 PUNCT
# кто 	 PRON
# больше 	 ADV
# трусил 	 VERB
# — 	 PUNCT
# Вильгельм 	 PROPN
# - 	 PROPN
# папа 	 NOUN
# или 	 CCONJ
# Телль 	 PROPN
# - 	 PROPN
# сын 	 NOUN
# . 	 PUNCT
# Но 	 CCONJ
#
#  	 SPACE
# Анка 	 NOUN
# - 	 NOUN
# то 	 DET
# чего 	 PRON
# ? 	 PUNCT
# Надо 	 ADV
# думать 	 VERB
# , 	 PUNCT
# перепугалась 	 VERB
# за 	 ADP
# Пашку 	 PROPN
# . 	 PUNCT
# А 	 CCONJ
# что 	 SCONJ
# мне 	 PRON
# было 	 AUX
# делать 	 VERB
# ? 	 PUNCT
# Вот 	 PART
# тащусь 	 VERB
# за 	 ADP
#
#  	 SPACE
# ними 	 PRON
# , 	 PUNCT
# как 	 SCONJ
# родственник 	 NOUN
# . 	 PUNCT
# Взять 	 VERB
# и 	 CCONJ
# уйти 	 VERB
# . 	 PUNCT
# Поверну 	 PROPN
# сейчас 	 ADV
# налево 	 ADV
# , 	 PUNCT
# там 	 ADV
# хорошее 	 ADJ
# болото 	 NOUN
# . 	 PUNCT
# Может 	 VERB
# , 	 PUNCT
#
#  	 SPACE
# сову 	 PROPN
# поймаю 	 VERB
# . 	 PUNCT
# Но 	 CCONJ
# он 	 PRON
# даже 	 PART
# не 	 PART
# замедлил 	 VERB
# шага 	 NOUN
# . 	 PUNCT
# Это 	 PRON
# значит 	 VERB
# навсегда 	 ADV
# , 	 PUNCT
# подумал 	 VERB
# он 	 PRON
# . 	 PUNCT
# Он 	 PRON
# читал 	 VERB
# , 	 PUNCT
# что 	 SCONJ
#
#  	 SPACE
# так 	 ADV
# бывает 	 VERB
# очень 	 ADV
# часто 	 ADV
# . 	 PUNCT
#
#        	 SPACE
# Они 	 PRON
# вышли 	 VERB
# на 	 ADP
# заброшенную 	 ADJ
# дорогу 	 NOUN
# даже 	 PART
# раньше 	 ADV
# , 	 PUNCT
# чем 	 SCONJ
# думали 	 VERB
# . 	 PUNCT
# Солнце 	 NOUN
# стояло 	 VERB
# высоко 	 ADV
# , 	 PUNCT
#
#  	 SPACE
# было 	 AUX
# жарко 	 ADJ
# . 	 PUNCT
# За 	 ADP
# шиворотом 	 NOUN
# кололись 	 VERB
# хвойные 	 ADJ
# иголки 	 NOUN
# . 	 PUNCT
# Дорога 	 NOUN
# была 	 AUX
# бетонная 	 ADJ
# , 	 PUNCT
# из 	 ADP
# двух 	 NUM
# рядов 	 NOUN
#
#  	 SPACE
# серо 	 ADJ
# - 	 ADJ
# рыжих 	 ADJ
# растрескавшихся 	 VERB
# плит 	 NOUN
# . 	 PUNCT
# В 	 ADP
# стыках 	 NOUN
# между 	 ADP
# плитами 	 NOUN
# росла 	 VERB
# густая 	 ADJ
# сухая 	 ADJ
# трава 	 NOUN
# . 	 PUNCT
# На 	 ADP
#
#  	 SPACE
# обочинах 	 NOUN
# было 	 AUX
# полно 	 ADV
# пыльного 	 ADJ
# репейника 	 NOUN
# . 	 PUNCT
# Над 	 ADP
# дорогой 	 NOUN
# с 	 ADP
# гудением 	 NOUN
# пролетали 	 VERB
# бронзовки 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
#
#  	 SPACE
# одна 	 DET
# нахально 	 ADV
# стукнула 	 VERB
# Антона 	 PROPN
# прямо 	 ADV
# в 	 ADP
# лоб 	 NOUN
# . 	 PUNCT
# Было 	 AUX
# тихо 	 ADJ
# и 	 CCONJ
# томно 	 ADJ
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Глядите 	 VERB
# ! 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#        	 SPACE
# Над 	 ADP
# серединой 	 NOUN
# дороги 	 NOUN
# на 	 ADP
# ржавой 	 ADJ
# проволоке 	 NOUN
# , 	 PUNCT
# протянутой 	 VERB
# поперек 	 NOUN
# , 	 PUNCT
# висел 	 VERB
# круглый 	 ADJ
#
#  	 SPACE
# жестяной 	 ADJ
# диск 	 NOUN
# , 	 PUNCT
# покрытый 	 VERB
# облупившейся 	 VERB
# краской 	 NOUN
# . 	 PUNCT
# Судя 	 VERB
# по 	 ADP
# всему 	 PRON
# , 	 PUNCT
# там 	 ADV
# был 	 AUX
# изображен 	 VERB
# желтый 	 ADJ
#
#  	 SPACE
# прямоугольник 	 NOUN
# на 	 ADP
# красном 	 ADJ
# фоне 	 NOUN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Что 	 PRON
# это 	 PRON
# ? 	 PUNCT
# — 	 PUNCT
# без 	 ADP
# особого 	 ADJ
# интереса 	 NOUN
# спросила 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# Автомобильный 	 ADJ
# знак 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# « 	 PUNCT
# Въезд 	 NOUN
# запрещен 	 VERB
# » 	 PUNCT
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# « 	 PUNCT
# Кирпич 	 PROPN
# » 	 PUNCT
# , 	 PUNCT
# — 	 PUNCT
# пояснил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
#
#        	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# зачем 	 ADV
# он 	 PRON
# ? 	 PUNCT
# — 	 PUNCT
# спросила 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Значит 	 VERB
# , 	 PUNCT
# вон 	 ADV
# туда 	 ADV
# ехать 	 VERB
# нельзя 	 ADV
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# А 	 CCONJ
# зачем 	 ADV
# тогда 	 ADV
# дорога 	 NOUN
# ? 	 PUNCT
#
#       	 SPACE
# Пашка 	 PROPN
# пожал 	 VERB
# плечами 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Это 	 PRON
# же 	 PART
# очень 	 ADV
# старое 	 ADJ
# шоссе 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# он 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Анизотропное 	 ADJ
# шоссе 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# заявил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# Анка 	 NOUN
# стояла 	 VERB
# к 	 ADP
# нему 	 PRON
# спиной 	 NOUN
# . 	 PUNCT
# — 	 PUNCT
# Движение 	 NOUN
#
#  	 SPACE
# только 	 PART
# в 	 ADP
# одну 	 NUM
# сторону 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Мудры 	 NOUN
# были 	 AUX
# предки 	 NOUN
# , 	 PUNCT
# задумчиво 	 ADV
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Этак 	 PROPN
# едешь 	 VERB
# - 	 NOUN
# едешь 	 VERB
# километров 	 NOUN
#
#  	 SPACE
# двести 	 NUM
# , 	 PUNCT
# вдруг 	 ADV
# — 	 PUNCT
# хлоп 	 NOUN
# ! 	 PUNCT
# — 	 PUNCT
# « 	 PUNCT
# кирпич 	 NOUN
# » 	 PUNCT
# . 	 PUNCT
# И 	 CCONJ
# ехать 	 VERB
# дальше 	 ADV
# нельзя 	 ADV
# , 	 PUNCT
# и 	 CCONJ
# спросить 	 VERB
# не 	 PART
# у 	 ADP
# кого 	 PRON
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Представляешь 	 VERB
# , 	 PUNCT
# что 	 SCONJ
# там 	 ADV
# может 	 VERB
# быть 	 AUX
# за 	 ADP
# этим 	 DET
# знаком 	 ADJ
# ! 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# . 	 PUNCT
# Она 	 PRON
#
#  	 SPACE
# огляделась 	 VERB
# . 	 PUNCT
# Кругом 	 NOUN
# на 	 ADP
# много 	 NUM
# километров 	 NOUN
# был 	 AUX
# безлюдный 	 ADJ
# лес 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# не 	 PART
# у 	 ADP
# кого 	 PRON
# было 	 AUX
# спросить 	 VERB
# , 	 PUNCT
# что 	 SCONJ
#
#  	 SPACE
# там 	 ADV
# может 	 VERB
# быть 	 AUX
# за 	 ADP
# этим 	 DET
# знаком 	 ADJ
# . 	 PUNCT
# — 	 PUNCT
# А 	 CCONJ
# вдруг 	 ADV
# это 	 PRON
# вовсе 	 ADV
# и 	 PART
# не 	 PART
# « 	 PUNCT
# кирпич 	 NOUN
# » 	 PUNCT
# ? 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# она 	 PRON
# . 	 PUNCT
# — 	 PUNCT
#
#  	 SPACE
# Краска 	 NOUN
# - 	 NOUN
# то 	 PROPN
# вся 	 DET
# облупилась 	 VERB
# … 	 PUNCT
#
#       	 SPACE
# Тогда 	 ADV
# Антон 	 PROPN
# тщательно 	 ADV
# прицелился 	 VERB
# и 	 CCONJ
# выстрелил 	 VERB
# . 	 PUNCT
# Было 	 AUX
# бы 	 AUX
# здорово 	 ADJ
# , 	 PUNCT
# если 	 SCONJ
# бы 	 AUX
# стрела 	 NOUN
#
#  	 SPACE
# перебила 	 VERB
# проволоку 	 NOUN
# и 	 CCONJ
# знак 	 NOUN
# упал 	 VERB
# бы 	 AUX
# прямо 	 ADV
# к 	 ADP
# ногам 	 NOUN
# Анки 	 PROPN
# . 	 PUNCT
# Но 	 CCONJ
# стрела 	 NOUN
# попала 	 VERB
# в 	 ADP
# верхнюю 	 ADJ
# часть 	 NOUN
#
#  	 SPACE
# знака 	 NOUN
# , 	 PUNCT
# пробила 	 VERB
# ржавую 	 ADJ
# жесть 	 NOUN
# , 	 PUNCT
# и 	 CCONJ
# вниз 	 ADV
# посыпалась 	 VERB
# только 	 PART
# высохшая 	 ADJ
# краска 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Дурак 	 PROPN
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# , 	 PUNCT
# не 	 PART
# оборачиваясь 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# Это 	 PRON
# было 	 AUX
# первое 	 ADJ
# слово 	 NOUN
# , 	 PUNCT
# с 	 ADP
# которым 	 PRON
# она 	 PRON
# обратилась 	 VERB
# к 	 ADP
# Антону 	 PROPN
# после 	 ADP
# игры 	 NOUN
# в 	 ADP
# Вильгельма 	 PROPN
#
#  	 SPACE
# Телля 	 PROPN
# . 	 PUNCT
# Антон 	 PROPN
# криво 	 ADV
# улыбнулся 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# « 	 PUNCT
# And 	 X
# enterprises 	 X
# of 	 X
# great 	 X
# and 	 X
# moment 	 X
# , 	 PUNCT
# — 	 PUNCT
# произнес 	 VERB
# он 	 PRON
# , 	 PUNCT
# — 	 PUNCT
# with 	 X
# this 	 X
# regard 	 X
# their 	 X
# current 	 X
#
#  	 SPACE
# turn 	 X
# away 	 X
# and 	 X
# loose 	 X
# name 	 X
# of 	 X
# action 	 X
# » 	 PUNCT
# . 	 PUNCT
# ( 	 PUNCT
# « 	 PUNCT
# И 	 CCONJ
# начинанья 	 NOUN
# , 	 PUNCT
# вознесшиеся 	 VERB
# мощно 	 ADV
# , 	 PUNCT
# сворачивая 	 VERB
# в 	 ADP
#
#  	 SPACE
# сторону 	 NOUN
# свой 	 DET
# ход 	 NOUN
# , 	 PUNCT
# теряют 	 VERB
# время 	 NOUN
# действия 	 NOUN
# » 	 PUNCT
# ( 	 PUNCT
# Шекспир 	 PROPN
# , 	 PUNCT
# « 	 PUNCT
# Гамлет 	 NOUN
# » 	 PUNCT
# ) 	 PUNCT
# . 	 PUNCT
#
#       	 SPACE
# Верный 	 ADJ
# Пашка 	 PROPN
# закричал 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ребята 	 NOUN
# , 	 PUNCT
# здесь 	 ADV
# прошла 	 VERB
# машина 	 NOUN
# ! 	 PUNCT
# Уже 	 ADV
# после 	 ADP
# грозы 	 NOUN
# ! 	 PUNCT
# Вон 	 PART
# трава 	 NOUN
# примята 	 VERB
# ! 	 PUNCT
# И 	 CCONJ
# вот 	 PART
# … 	 PUNCT
#
#       	 SPACE
# Везет 	 VERB
# Пашке 	 PROPN
# , 	 PUNCT
# подумал 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# Он 	 PRON
# стал 	 VERB
# разглядывать 	 VERB
# следы 	 NOUN
# на 	 ADP
# дороге 	 NOUN
# и 	 CCONJ
# тоже 	 ADV
# увидел 	 VERB
#
#  	 SPACE
# примятую 	 ADJ
# траву 	 NOUN
# и 	 CCONJ
# черную 	 ADJ
# полосу 	 NOUN
# от 	 ADP
# протекторов 	 NOUN
# в 	 ADP
# том 	 DET
# месте 	 NOUN
# , 	 PUNCT
# где 	 ADV
# автомобиль 	 NOUN
# затормозил 	 VERB
#
#  	 SPACE
# перед 	 ADP
# выбоиной 	 ADJ
# в 	 ADP
# бетоне 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ага 	 PROPN
# ! 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Он 	 PRON
# выскочил 	 VERB
# из 	 ADP
# - 	 ADP
# под 	 ADP
# знака 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Это 	 PRON
# было 	 AUX
# ясно 	 ADJ
# каждому 	 DET
# , 	 PUNCT
# но 	 CCONJ
# Антон 	 PROPN
# возразил 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ничего 	 PRON
# подобного 	 ADJ
# , 	 PUNCT
# он 	 PRON
# ехал 	 VERB
# с 	 ADP
# той 	 DET
# стороны 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Пашка 	 PROPN
# поднял 	 VERB
# на 	 ADP
# него 	 PRON
# изумленные 	 ADJ
# глаза 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ты 	 PRON
# что 	 PRON
# , 	 PUNCT
# ослеп 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Он 	 PRON
# ехал 	 VERB
# с 	 ADP
# той 	 DET
# стороны 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# упрямо 	 NOUN
# повторил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Пошли 	 VERB
# по 	 ADP
# следу 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Ерунду 	 PROPN
# ты 	 PRON
# городишь 	 VERB
# ! 	 PUNCT
# — 	 PUNCT
# возмутился 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Во 	 ADV
# - 	 ADV
# первых 	 ADV
# , 	 PUNCT
# никакой 	 DET
# порядочный 	 ADJ
#
#  	 SPACE
# водитель 	 NOUN
# не 	 PART
# поедет 	 VERB
# под 	 ADP
# « 	 PUNCT
# кирпич 	 NOUN
# » 	 PUNCT
# . 	 PUNCT
# Во 	 ADV
# - 	 ADV
# вторых 	 ADV
# , 	 PUNCT
# смотри 	 VERB
# : 	 PUNCT
# вот 	 PART
# выбоина 	 NOUN
# , 	 PUNCT
# вот 	 PART
# тормозной 	 ADJ
# след 	 NOUN
# … 	 PUNCT
#
#  	 SPACE
# Так 	 ADV
# откуда 	 ADV
# он 	 PRON
# ехал 	 VERB
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Что 	 SCONJ
# мне 	 PRON
# твои 	 DET
# порядочные 	 ADJ
# ! 	 PUNCT
# Я 	 PRON
# сам 	 ADJ
# непорядочный 	 ADJ
# , 	 PUNCT
# и 	 CCONJ
# я 	 PRON
# пойду 	 VERB
# под 	 ADP
# знак 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# Пашка 	 PROPN
# взбеленился 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Иди 	 VERB
# куда 	 ADV
# хочешь 	 VERB
# ! 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# он 	 PRON
# , 	 PUNCT
# слегка 	 ADV
# заикаясь 	 VERB
# . 	 PUNCT
# — 	 PUNCT
# Недоумок 	 PROPN
# . 	 PUNCT
# Совсем 	 ADV
# обалдел 	 VERB
# от 	 ADP
#
#  	 SPACE
# жары 	 NOUN
# ! 	 PUNCT
#
#       	 SPACE
# Антон 	 PROPN
# повернулся 	 VERB
# и 	 CCONJ
# , 	 PUNCT
# глядя 	 VERB
# прямо 	 ADV
# перед 	 ADP
# собой 	 PRON
# , 	 PUNCT
# пошел 	 VERB
# под 	 ADP
# знак 	 NOUN
# . 	 PUNCT
# Ему 	 PRON
# хотелось 	 VERB
# только 	 PART
#
#  	 SPACE
# одного 	 NUM
# : 	 PUNCT
# чтобы 	 SCONJ
# впереди 	 ADV
# оказался 	 VERB
# какой 	 DET
# - 	 DET
# нибудь 	 DET
# взорванный 	 ADJ
# мост 	 NOUN
# и 	 CCONJ
# чтобы 	 SCONJ
# нужно 	 ADJ
# было 	 AUX
#
#  	 SPACE
# прорваться 	 VERB
# на 	 ADP
# ту 	 DET
# сторону 	 NOUN
# . 	 PUNCT
# Какое 	 DET
# мне 	 PRON
# дело 	 NOUN
# до 	 ADP
# этого 	 PRON
# порядочного 	 NOUN
# ! 	 PUNCT
# — 	 PUNCT
# думал 	 VERB
# он 	 PRON
# . 	 PUNCT
# — 	 PUNCT
# Пусть 	 PART
# идут 	 VERB
# , 	 PUNCT
#
#  	 SPACE
# куда 	 ADV
# хотят 	 VERB
# … 	 PUNCT
# со 	 ADP
# своим 	 DET
# Пашенькой 	 PROPN
# . 	 PUNCT
# Он 	 PRON
# вспомнил 	 VERB
# , 	 PUNCT
# как 	 SCONJ
# Анка 	 PROPN
# срезала 	 VERB
# Павла 	 PROPN
# , 	 PUNCT
# когда 	 SCONJ
# тот 	 DET
# назвал 	 VERB
# ее 	 PRON
#
#  	 SPACE
# Анечкой 	 PROPN
# , 	 PUNCT
# и 	 CCONJ
# ему 	 PRON
# стало 	 VERB
# немного 	 ADV
# легче 	 ADJ
# . 	 PUNCT
# Он 	 PRON
# оглянулся 	 VERB
# . 	 PUNCT
#
#       	 SPACE
# Пашку 	 NOUN
# он 	 PRON
# увидел 	 VERB
# сразу 	 ADV
# : 	 PUNCT
# Бон 	 PROPN
# Саранча 	 PROPN
# , 	 PUNCT
# согнувшись 	 VERB
# в 	 ADP
# три 	 NUM
# погибели 	 NOUN
# , 	 PUNCT
# шел 	 VERB
# по 	 ADP
# следу 	 NOUN
#
#  	 SPACE
# таинственной 	 ADJ
# машины 	 NOUN
# . 	 PUNCT
# Ржавый 	 ADJ
# диск 	 NOUN
# над 	 ADP
# дорогой 	 NOUN
# тихонько 	 ADV
# покачивался 	 VERB
# , 	 PUNCT
# и 	 CCONJ
# сквозь 	 ADP
# дырку 	 NOUN
#
#  	 SPACE
# мелькало 	 VERB
# синее 	 ADJ
# небо 	 NOUN
# . 	 PUNCT
# А 	 CCONJ
# на 	 ADP
# обочине 	 NOUN
# сидела 	 VERB
# Анка 	 PROPN
# , 	 PUNCT
# уперев 	 VERB
# локти 	 NOUN
# в 	 ADP
# голые 	 ADJ
# колени 	 NOUN
# и 	 CCONJ
# положив 	 VERB
#
#  	 SPACE
# подбородок 	 NOUN
# на 	 ADP
# сжатые 	 VERB
# кулаки 	 NOUN
# . 	 PUNCT
#
#
#       	 SPACE
# … 	 PUNCT
# Они 	 PRON
# возвращались 	 VERB
# уже 	 ADV
# в 	 ADP
# сумерках 	 NOUN
# . 	 PUNCT
# Ребята 	 NOUN
# гребли 	 VERB
# , 	 PUNCT
# а 	 CCONJ
# Анка 	 PROPN
# сидела 	 VERB
# на 	 ADP
# руле 	 NOUN
# . 	 PUNCT
# Над 	 ADP
#
#  	 SPACE
# черным 	 ADJ
# лесом 	 NOUN
# поднималась 	 VERB
# красная 	 ADJ
# луна 	 NOUN
# , 	 PUNCT
# неистово 	 ADV
# вопили 	 VERB
# лягушки 	 NOUN
# . 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Так 	 ADV
# здорово 	 ADV
# все 	 PRON
# было 	 AUX
# задумано 	 VERB
# , 	 PUNCT
# — 	 PUNCT
# сказала 	 VERB
# Анка 	 PROPN
# грустно 	 ADJ
# . 	 PUNCT
# — 	 PUNCT
# Эх 	 PROPN
# , 	 PUNCT
# вы 	 PRON
# ! 	 PUNCT
# .. 	 PUNCT
#
#       	 SPACE
# Ребята 	 NOUN
# промолчали 	 VERB
# . 	 PUNCT
# Затем 	 ADV
# Пашка 	 PROPN
# вполголоса 	 NOUN
# спросил 	 VERB
# : 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Тошка 	 NOUN
# , 	 PUNCT
# что 	 PRON
# там 	 ADV
# было 	 VERB
# , 	 PUNCT
# под 	 ADP
# знаком 	 NOUN
# ? 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Взорванный 	 ADJ
# мост 	 NOUN
# , 	 PUNCT
# — 	 PUNCT
# ответил 	 VERB
# Антон 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# И 	 CCONJ
# скелет 	 NOUN
# фашиста 	 NOUN
# , 	 PUNCT
# прикованный 	 VERB
# цепями 	 NOUN
# к 	 ADP
#
#  	 SPACE
# пулемету 	 NOUN
# . 	 PUNCT
# Он 	 PRON
# подумал 	 VERB
# и 	 CCONJ
# добавил 	 VERB
# : 	 PUNCT
# — 	 PUNCT
# Пулемет 	 NOUN
# весь 	 DET
# врос 	 VERB
# в 	 ADP
# землю 	 NOUN
# … 	 PUNCT
#
#       	 SPACE
# — 	 PUNCT
# Н 	 PROPN
# - 	 NOUN
# да 	 PART
# … 	 PUNCT
# — 	 PUNCT
# сказал 	 VERB
# Пашка 	 PROPN
# . 	 PUNCT
# — 	 PUNCT
# Бывает 	 VERB
# . 	 PUNCT
# А 	 CCONJ
# я 	 PRON
# там 	 ADV
# одному 	 NUM
# машину 	 NOUN
# помог 	 VERB
# починить 	 VERB
# . 	 PUNCT
#
#
#                                            	 SPACE
# 1 	 NUM
#
#      	 SPACE

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="5389e312db904578bca01cfb0317066b-0" class="displacy" width="606950" height="1099.5" direction="ltr" style="max-width: none; height: 1099.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
#      </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Ложа</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Анкиного</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">арбалета</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">была</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">выточена</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">из</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">черной</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">пластмассы,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">а</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">тетива</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">была</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">из</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">хромистой</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">стали</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">и</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">натягивалась</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">одним</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">движением</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">бесшумно</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">скользящего</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">рычага.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Антон</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">новшеств</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">не</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">признавал:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">у</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">него</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">

# %%
from natasha import Segmenter, NewsEmbedding, NewsSyntaxParser, Doc

emb = NewsEmbedding()

segmenter = Segmenter()

syntax_parser = NewsSyntaxParser(emb)

text = ' Ложа Анкиного арбалета была выточена из черной пластмассы, а тетива была из хромистой стали и натягивалась одним движением бесшумно скользящего рычага.'

doc = Doc(text)

doc.segment(segmenter)

for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(start=1, stop=5, text='Ложа')
# DocToken(start=6, stop=14, text='Анкиного')
# DocToken(start=15, stop=23, text='арбалета')
# DocToken(start=24, stop=28, text='была')
# DocToken(start=29, stop=37, text='выточена')
# DocToken(start=38, stop=40, text='из')
# DocToken(start=41, stop=47, text='черной')
# DocToken(start=48, stop=58, text='пластмассы')
# DocToken(start=58, stop=59, text=',')
# DocToken(start=60, stop=61, text='а')
# DocToken(start=62, stop=68, text='тетива')
# DocToken(start=69, stop=73, text='была')
# DocToken(start=74, stop=76, text='из')
# DocToken(start=77, stop=86, text='хромистой')
# DocToken(start=87, stop=92, text='стали')
# DocToken(start=93, stop=94, text='и')
# DocToken(start=95, stop=107, text='натягивалась')
# DocToken(start=108, stop=113, text='одним')
# DocToken(start=114, stop=123, text='движением')
# DocToken(start=124, stop=132, text='бесшумно')
# DocToken(start=133, stop=144, text='скользящего')
# DocToken(start=145, stop=151, text='рычага')
# DocToken(start=151, stop=152, text='.')

# %%
doc.parse_syntax(syntax_parser)

for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(start=1, stop=5, text='Ложа', id='1_1', head_id='1_5', rel='nsubj:pass')
# DocToken(start=6, stop=14, text='Анкиного', id='1_2', head_id='1_3', rel='amod')
# DocToken(start=15, stop=23, text='арбалета', id='1_3', head_id='1_1', rel='nmod')
# DocToken(start=24, stop=28, text='была', id='1_4', head_id='1_15', rel='cop')
# DocToken(start=29, stop=37, text='выточена', id='1_5', head_id='1_0', rel='root')
# DocToken(start=38, stop=40, text='из', id='1_6', head_id='1_8', rel='case')
# DocToken(start=41, stop=47, text='черной', id='1_7', head_id='1_8', rel='amod')
# DocToken(start=48, stop=58, text='пластмассы', id='1_8', head_id='1_5', rel='obl')
# DocToken(start=58, stop=59, text=',', id='1_9', head_id='1_11', rel='punct')
# DocToken(start=60, stop=61, text='а', id='1_10', head_id='1_11', rel='cc')
# DocToken(start=62, stop=68, text='тетива', id='1_11', head_id='1_15', rel='conj')
# DocToken(start=69, stop=73, text='была', id='1_12', head_id='1_15', rel='cop')
# DocToken(start=74, stop=76, text='из', id='1_13', head_id='1_14', rel='case')
# DocToken(start=77, stop=86, text='хромистой', id='1_14', head_id='1_5', rel='obl')
# DocToken(start=87, stop=92, text='стали', id='1_15', head_id='1_0', rel='root')
# DocToken(start=93, stop=94, text='и', id='1_16', head_id='1_17', rel='cc')
# DocToken(start=95, stop=107, text='натягивалась', id='1_17', head_id='1_15', rel='conj')
# DocToken(start=108, stop=113, text='одним', id='1_18', head_id='1_19', rel='nummod')
# DocToken(start=114, stop=123, text='движением', id='1_19', head_id='1_17', rel='obl')
# DocToken(start=124, stop=132, text='бесшумно', id='1_20', head_id='1_8', rel='advmod')
# DocToken(start=133, stop=144, text='скользящего', id='1_21', head_id='1_22', rel='amod')
# DocToken(start=145, stop=151, text='рычага', id='1_22', head_id='1_17', rel='obl')
# DocToken(start=151, stop=152, text='.', id='1_23', head_id='1_5', rel='punct')

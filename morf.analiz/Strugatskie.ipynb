# %%
## Импорт библиотеки, загрузка моделей и словаря wordnet
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Хороший
# [nltk_data]     человек\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Хороший человек\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to C:\Users\Хороший
# [nltk_data]     человек\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
with open('Далёкая радуга.txt', 'r', encoding='utf-8') as file:
    raduga = file.read()
print(raduga)
# Out:
#               Аркадий Стругацкий, Борис Стругацкий
#                          Далёкая Радуга
#                                            1
#      Танина ладонь, тёплая и немного шершавая, лежала у него на глазах, и больше ему ни
# до чего не было дела. Он чувствовал горько–солёный запах пыли, скрипели спросонок
# степные птицы, и сухая трава колола и щекотала затылок. Лежать было жёстко и неудобно,
# шея чесалась нестерпимо, но он не двигался, слушая тихое, ровное дыхание Тани. Он
# улыбался и радовался темноте, потому что улыбка была, наверное, до неприличия глупой и
# довольной.
#      Потом не к месту и не ко времени в лаборатории на вышке заверещал сигнал вызова.
# Пусть! Не первый раз. В этот вечер все вызовы не к месту и не ко времени.
#      – Робик, – шёпотом сказала Таня. – Слышишь?
#      – Совершенно ничего не слышу, – пробормотал Роберт.
#      Он помигал, чтобы пощекотать Танину ладонь ресницами. Всё было далеко–далеко и
# ...

# %%
# Токенизация текста
tokenized = nltk.word_tokenize(raduga)
tokenized
# Out:
# ['Аркадий',
#  'Стругацкий',
#  ',',
#  'Борис',
#  'Стругацкий',
#  'Далёкая',
#  'Радуга',
#  '1',
#  'Танина',
#  'ладонь',
#  ',',
#  'тёплая',
#  'и',
#  'немного',
#  'шершавая',
#  ',',
#  'лежала',
#  'у',
#  'него',
#  'на',
#  'глазах',
#  ',',
#  'и',
#  'больше',
#  'ему',
#  'ни',
#  'до',
#  'чего',
#  'не',
#  'было',
#  'дела',
#  '.',
#  'Он',
#  'чувствовал',
#  'горько–солёный',
#  'запах',
#  'пыли',
#  ',',
#  'скрипели',
#  'спросонок',
#  'степные',
#  'птицы',
#  ',',
#  'и',
#  'сухая',
#  'трава',
#  'колола',
#  'и',
#  'щекотала',
#  'затылок',
#  '.',
#  'Лежать',
#  'было',
#  'жёстко',
#  'и',
#  'неудобно',
#  ',',
#  'шея',
#  'чесалась',
#  'нестерпимо',
#  ',',
#  'но',
#  'он',
#  'не',
#  'двигался',
#  ',',
#  'слушая',
#  'тихое',
#  ',',
#  'ровное',
#  'дыхание',
#  'Тани',
#  '.',
#  'Он',
#  'улыбался',
#  'и',
#  'радовался',
#  'темноте',
#  ',',
#  'потому',
#  'что',
#  'улыбка',
#  'была',
#  ',',
#  'наверное',
#  ',',
#  'до',
# ...

# %%
# разбор по частям речи
tagged = nltk.pos_tag(tokenized)
tagged
# Out:
# [('Аркадий', 'NN'),
#  ('Стругацкий', 'NN'),
#  (',', ','),
#  ('Борис', 'NNP'),
#  ('Стругацкий', 'NNP'),
#  ('Далёкая', 'NNP'),
#  ('Радуга', 'VBD'),
#  ('1', 'CD'),
#  ('Танина', 'NNP'),
#  ('ладонь', 'NNP'),
#  (',', ','),
#  ('тёплая', 'NNP'),
#  ('и', 'NNP'),
#  ('немного', 'NNP'),
#  ('шершавая', 'NNP'),
#  (',', ','),
#  ('лежала', 'NNP'),
#  ('у', 'NNP'),
#  ('него', 'NNP'),
#  ('на', 'NNP'),
#  ('глазах', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('больше', 'NNP'),
#  ('ему', 'NNP'),
#  ('ни', 'NNP'),
#  ('до', 'NNP'),
#  ('чего', 'NNP'),
#  ('не', 'NNP'),
#  ('было', 'NNP'),
#  ('дела', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('чувствовал', 'JJ'),
#  ('горько–солёный', 'NNP'),
#  ('запах', 'NNP'),
#  ('пыли', 'NNP'),
#  (',', ','),
#  ('скрипели', 'NNP'),
#  ('спросонок', 'NNP'),
#  ('степные', 'NNP'),
#  ('птицы', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('сухая', 'NNP'),
#  ('трава', 'NNP'),
#  ('колола', 'NNP'),
#  ('и', 'NNP'),
#  ('щекотала', 'NNP'),
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
lemmatized = [lemm.lemmatize(word) for word in tokenized]
lemmatized
# Out:
# ['Аркадий',
#  'Стругацкий',
#  ',',
#  'Борис',
#  'Стругацкий',
#  'Далёкая',
#  'Радуга',
#  '1',
#  'Танина',
#  'ладонь',
#  ',',
#  'тёплая',
#  'и',
#  'немного',
#  'шершавая',
#  ',',
#  'лежала',
#  'у',
#  'него',
#  'на',
#  'глазах',
#  ',',
#  'и',
#  'больше',
#  'ему',
#  'ни',
#  'до',
#  'чего',
#  'не',
#  'было',
#  'дела',
#  '.',
#  'Он',
#  'чувствовал',
#  'горько–солёный',
#  'запах',
#  'пыли',
#  ',',
#  'скрипели',
#  'спросонок',
#  'степные',
#  'птицы',
#  ',',
#  'и',
#  'сухая',
#  'трава',
#  'колола',
#  'и',
#  'щекотала',
#  'затылок',
#  '.',
#  'Лежать',
#  'было',
#  'жёстко',
#  'и',
#  'неудобно',
#  ',',
#  'шея',
#  'чесалась',
#  'нестерпимо',
#  ',',
#  'но',
#  'он',
#  'не',
#  'двигался',
#  ',',
#  'слушая',
#  'тихое',
#  ',',
#  'ровное',
#  'дыхание',
#  'Тани',
#  '.',
#  'Он',
#  'улыбался',
#  'и',
#  'радовался',
#  'темноте',
#  ',',
#  'потому',
#  'что',
#  'улыбка',
#  'была',
#  ',',
#  'наверное',
#  ',',
#  'до',
# ...

# %%
from collections import Counter
import nltk
nltk.download('punkt')

words = nltk.word_tokenize(raduga)
word_frequency = Counter(words)

print(word_frequency)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Хороший
# [nltk_data]     человек\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

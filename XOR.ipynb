# %%
# %pip install -q tensorflow numpy protobuf==3.20.3

import tensorflow as tf
import numpy as np
from random import randint
# Out:
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Входные данные и лейблы
X = np.array([[-1, -1], [-1, 1], [1, -1], [1, 1]], dtype=np.float32)
Y = np.array([0, 1, 1, 0], dtype=np.float32)

# Создание модели нейронной сети
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(2, input_dim=2, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Компиляция модели
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Обучение модели
model.fit(X, Y, epochs=500, verbose=1)

# Оценка модели на входных данных
loss, accuracy = model.evaluate(X, Y, verbose=0)
print(f'Accuracy: {accuracy}')

# Прогнозирование на новых данных
predictions = model.predict(X)
print('Predictions:')
for i in range(len(X)):
    print(f'X={X[i]}, Predicted={predictions[i]}')
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 719ms/step - loss: 0.6844 - accuracy: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6832 - accuracy: 0.7500
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6819 - accuracy: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6807 - accuracy: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6794 - accuracy: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6782 - accuracy: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6770 - accuracy: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6757 - accuracy: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6745 - accuracy: 0.7500
# Epoch 10/500
# ...
